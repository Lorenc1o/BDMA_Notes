# %% [markdown]
# # Web Scraping Tutorial
#
# This tutorial will teach you how Python to scrap and extract data from a web page. We will use two packages, `requests` to scrap the webpage and `BeautifulSoup` to extract the data.
#
# Many good references on web scraping are available online. I would recommend the following resources:
# 1. Automate Boring Stuff with Python by Al Sweigart (2020) has a chapter on Web Scraping tutorial, which can be read [online](https://automatetheboringstuff.com/2e/chapter12/).
# 2. Web Scraping With Python by Ryan Mitchell (2018) is a bit old book but provides a comprehensive guide to the topic.
#
# **Goal:** We will extract the cryptocurrency market price from Etherscan website: https://etherscan.io/tokens
#
# Your first step should always be to familiarize yourself with the website you want to scrape. Take a look at the website and try to inspect the HTML elements on the webpage.

# %% [markdown]
# ## Step 1: Scrap a web page
#
# Now, we are ready to scrap a webpage we want to get the data from with the `requests` package. We will use the following functions:
#
# * `requests.get('URL')` - make a request to the specified URL
# * `r.status_code` - get the status code of the request
# * `r.content` - get the binary content of the page
#
# More functions in the `requests` package are available in [its documentation](https://requests.readthedocs.io/en/latest/).

# %%
# First, we will import the requests package
import requests

# %%
# Request the webpage
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
r = requests.get('https://etherscan.io/tokens?ps=100&p=1', headers=headers)

# %%
# Type of the request object we've got
type(r)
# Out:
# requests.models.Response

# %%
# Check if the request is success
r.status_code == requests.codes.ok
# Out:
# True

# %%
# Get the header of the web page
r.headers['content-type']
# Out:
# 'text/html; charset=utf-8'

# %%
# Get the content of the web page
type(r.content)
# Out:
# bytes

# %%
# Get the text in the web page
type(r.text)
# Out:
# str

# %%
# Save the content of web page
with open('Etherscan.html', 'wb') as fp:
    fp.write(r.content)

# %% [markdown]
# ## Step 2: Load the web page as BeautifulSoup object
#
# After we crawled the web page and download it to the local disk, we will use `BeautifulSoup` package to parse HTML file and access the content. We will use the following functions:
#
# **1. Load the web page to BeautifulSoup**
# * `soup = BeautifulSoup(html_doc, 'html.parser')` - parse the HTML content to BeautifulSoup object

# %%
# First, we will import the BeautifulSoup from bs4 package
from bs4 import BeautifulSoup

# %%
# Load the web page and parse it to BeautifulSoup
with open('Etherscan.html', encoding='utf-8') as fp:
    soup = BeautifulSoup(fp, 'html.parser')

# %%
# Check the type of our soup object
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Print the content of the web page
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html id="html" lang="en">
#  <head>
#   <title>
#    Token Tracker | Etherscan
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="etherscan.io" name="author"/>
#   <meta content="The list of ERC-20 Tokens and their Prices, Market Capitalizations and the Number of Holders in the Ethereum Blockchain on Etherscan." name="Description"/>
#   <meta content="ethereum, explorer, ether, search, blockchain, crypto, currency" name="keywords"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="Token Tracker | Etherscan" property="og:title"/>
#   <meta content="The list of ERC-20 Tokens and their Prices, Market Capitalizations and the Number of Holders in the Ethereum Blockchain on Etherscan." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Ethereum (ETH) Blockchain Explorer" property="og:site_name"/>
#   <meta content="http://etherscan.io/tokens" property="og:url"/>
#   <meta content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" property="og:image"/>
#   <meta content="https://etherscan.io/images/brandassets/etherscan-logo-r.jpg" property="og:image:url"/>
#   <meta content="Visit Etherscan.io" property="og:image:alt"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Token Tracker | Etherscan" name="twitter:title"/>
#   <meta content="The list of ERC-20 Tokens and their Prices, Market Capitalizations and the Number of Holders in the Ethereum Blockchain on Etherscan." property="twitter:description"/>
#   <meta content="@etherscan" name="twitter:site"/>
#   <meta content="https://etherscan.io/images/brandassets/etherscan-logo-circle.jpg" property="twitter:image"/>
#   <link href="/images/favicon3.ico" rel="shortcut icon"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-T1JC9RNQXV">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config','G-T1JC9RNQXV', { 'anonymize_ip': true });
#   </script>
#   <script>
#    //Search box text ad
#         var availableAd = [];
#         var gotAd = [];
#
#
#         availableAd = ["<div class='p-2'><a href='https://moonpay-affiliate-program.sjv.io/GmG56B' rel='nofollow' target='_blank' data-bs-toggle='tooltip' data-bs-trigger='hover' title='Links to an External Advertiser site' class='search-panel-ads d-flex align-items-center p-2 rounded'><div class='me-2'><img width='22' class='rounded-1' src='/images/gen/moonpay_20.png' alt='Ads'></div><div class='text-truncate'><h6 class='d-flex align-items-center fs-sm text-dark mb-0'><div class='text-truncate me-2'>Moonpay: Buy & Sell Crypto with a credit card.</div><span class='d-none d-sm-inline-block small bg-white text-muted rounded-1 border px-2 py-1 ms-1'>Sponsored</span><span class='d-inline-block d-sm-none small bg-white text-muted rounded-1 border px-2 py-1 ms-1'>Ad</span></h6></div></a></div>"];
#         gotAd = ["ShowAds					"];
#   </script>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
#   <link href="/assets/vendor/font-awesome/css/all.min.css?v=23.9.4.0" rel="stylesheet"/>
#   <link href="/assets/vendor/autocomplete/dist/css/autocomplete.min.css?v=23.9.4.0" rel="stylesheet">
#    <link href="/assets/css/theme.min.css?v=23.9.4.0" rel="stylesheet"/>
#    <link href="/assets/css/custom.css?v=23.9.4.0" rel="stylesheet"/>
#    <script src="/assets/vendor/jquery/dist/jquery.min.js?v=23.9.4.0">
#    </script>
#    <script src="/jss/blockies.js?v=23.9.4.0" type="text/javascript">
#    </script>
#    <script src="/assets/js/theme-appearance.js?v=23.9.4.0" type="text/javascript">
#    </script>
#    <style>
#     .autolink-safari a {
#             pointer-events: none !important;
#             text-decoration: none !important;
#             color: inherit !important;
#         }
#    </style>
#    <style>
#     .ddkklw4jc87 { -ms-flex-pack: center; justify-content: center; } .a4drprregh4 { border-top: 1px solid #e7eaf3 !important; } body.dark-mode .a4drprregh4 { border-color: #18365b !important; } @media (min-width: 992px) { .bc7s3diuf1i { display: block !important; } } @media (min-width: 992px) { .cb7kre1lbu3 { display: inline-block !important; } }
#    </style>
#    <link href="/assets/vendor/datatables/datatables.min.css?v=23.9.4.0" rel="stylesheet" type="text/css">
#     <style>
#      .dataTable > thead > tr > th[class*="sort"]:before,
#         .dataTable > thead > tr > th[class*="sort"]:after {
#             content: "" !important;
#         }
#
#         .dataTables_processing {
#             z-index: 100;
#         }
#     </style>
#    </link>
#   </link>
#  </head>
#  <body class="d-flex flex-column min-vh-100" id="body">
#   <section id="masterNoticeBar">
#   </section>
#   <section class="sticky-top bg-white border-bottom py-2 d-print-none" id="masterTopBar">
#    <div class="container-xxl d-flex align-items-center justify-content-between">
#     <div class="d-none d-md-flex align-items-center gap-4 w-100 fs-sm" id="ethPrice">
#      <div class="text-muted">
#       <span class="text-muted">
#        ETH Price:
#       </span>
#       <a href="/chart/etherprice">
#        $1,637.95
#       </a>
#       <span data-bs-placement="top" data-bs-toggle="tooltip" title="Changes in the last 24 hours">
#        <span class="text-danger">
#         (-0.52%)
#        </span>
#       </span>
#      </div>
#      <div class="text-muted d-none d-lg-block">
#       <i class="fad fa-gas-pump me-1">
#       </i>
#       Gas:
#       <span data-bs-html="true" data-bs-toggle="tooltip" id="spanGasTooltip" title="Base Fee: 6 Gwei&lt;br&gt;Priority Fee: 0 Gwei">
#        <a href="/gastracker">
#         <span class="gasPricePlaceHolder">
#          6
#         </span>
#         Gwei
#        </a>
#       </span>
#      </div>
#     </div>
#     <div class="d-flex justify-content-end align-items-center gap-2 w-100">
#      <div class="search-panel-container flex-grow-1 position-relative" id="frmMaster" style="width: 30rem;">
#       <form action="/search" autocomplete="off" class="auto-search-max-height" method="GET" spellcheck="false">
#        <span class="d-flex align-items-center position-absolute top-0 bottom-0" style="left: 0.75rem;" title="Search">
#         <i class="fa-regular fa-search fs-5 text-secondary">
#         </i>
#        </span>
#        <input aria-describedby="button-header-search" autocomplete="off" class="form-control form-control-lg bg-light bg-focus-white pe-20" id="search-panel" maxlength="68" name="q" onkeyup="handleSearchText(this);" placeholder="Search by Address / Txn Hash / Block / Token / Domain Name" spellcheck="false" style="padding-left: 2.375rem;" type="text"/>
#        <a class="clear-icon d-none align-items-center position-absolute top-0 bottom-0 my-auto d-flex align-items-center" href="javascript:;" style="right: 3.375rem; cursor:pointer;">
#         <i class="fa-regular fa-xmark fs-5 text-secondary">
#         </i>
#        </a>
#        <a class="search-icon d-none btn btn-sm btn-white my-1.5 align-items-center position-absolute top-0 bottom-0 d-flex align-items-center" href="javascript:;" style="right: 0.75rem; cursor:pointer;">
#         <i class="fa-regular fa-arrow-turn-down-left text-secondary">
#         </i>
#        </a>
#        <input id="hdnSearchText" type="hidden" value=""/>
#        <input id="hdnSearchLabel" type="hidden" value=""/>
#        <input id="hdnIsTestNet" type="hidden" value="False"/>
#        <span class="shortcut-slash-icon align-items-center position-absolute top-0 bottom-0 align-items-center d-none d-sm-flex" style="right: 0.5rem;" title="Search">
#         <kbd class="bg-dark bg-opacity-25 fw-semibold px-2 py-0.5 text-white">
#          /
#         </kbd>
#        </span>
#       </form>
#      </div>
#      <div class="dropdown d-none d-lg-block" id="divThemeSetting">
#       <button aria-expanded="false" class="btn btn-lg btn-white text-primary content-center" data-bs-auto-close="outside" data-bs-toggle="dropdown" id="dropdownMenuTopbarSettings" style="width: 2.375rem; height: 2.375rem;" type="button">
#        <span class="theme-btn-main">
#         <i class="far fa-sun-bright theme-icon-active" data-href="#fa-sun-bright">
#         </i>
#        </span>
#       </button>
#       <ul aria-labelledby="dropdownMenuTopbarSettings" class="dropdown-menu dropdown-menu-end">
#        <li>
#         <button class="dropdown-item theme-btn active" data-bs-theme-value="light" onclick="setThemeMode('light');" type="button">
#          <i class="far fa-sun-bright fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-sun-bright">
#          </i>
#          Light
#         </button>
#        </li>
#        <li>
#         <button class="dropdown-item theme-btn" data-bs-theme-value="dim" onclick="setThemeMode('dim');" type="button">
#          <i class="far fa-moon-stars fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon-stars">
#          </i>
#          Dim
#         </button>
#        </li>
#        <li>
#         <button class="dropdown-item theme-btn" data-bs-theme-value="dark" onclick="setThemeMode('dark');" type="button">
#          <i class="far fa-moon fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon">
#          </i>
#          Dark
#         </button>
#        </li>
#        <li>
#         <hr class="dropdown-divider"/>
#        </li>
#        <li>
#         <a class="dropdown-item" href="/settings">
#          <i class="far fa-gear fa-fw dropdown-item-icon me-1">
#          </i>
#          Site Settings
#          <i class="far fa-arrow-right ms-1">
#          </i>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="dropdown d-none d-lg-block" id="divTestNet">
#       <button aria-expanded="false" class="btn btn-lg btn-white content-center" data-bs-toggle="dropdown" id="dropdownTopbarNetworks" style="width: 2.375rem; height: 2.375rem;" type="button">
#        <img alt="Ethereum Logo" data-img-theme="light" src="/images/svg/brands/ethereum-original.svg" width="10"/>
#        <img alt="Ethereum Logo" data-img-theme="darkmode" src="/images/svg/brands/ethereum-original-light.svg" width="10"/>
#       </button>
#       <ul aria-labelledby="dropdownTopbarNetworks" class="dropdown-menu dropdown-menu-end">
#        <li>
#         <a class="dropdown-item active active" href="https://etherscan.io" id="LI_Mainnet">
#          Ethereum Mainnet
#         </a>
#        </li>
#        <li>
#         <a class="dropdown-item" href="https://cn.etherscan.com/?lang=zh-CN" id="LI_Mainnet_CN">
#          Ethereum Mainnet
#          <span class="badge border bg-light text-dark ms-1">
#           CN
#          </span>
#         </a>
#        </li>
#        <li>
#         <a class="dropdown-item" href="https://beaconscan.com/" id="LI2">
#          Beaconscan
#          <span class="badge border bg-light text-dark ms-1">
#           ETH2
#          </span>
#         </a>
#        </li>
#        <li>
#         <hr class="dropdown-divider"/>
#        </li>
#        <li>
#         <a class="dropdown-item" href="https://goerli.etherscan.io" id="LI58">
#          Goerli Testnet
#         </a>
#        </li>
#        <li>
#         <a class="dropdown-item" href="https://sepolia.etherscan.io" id="LI9">
#          Sepolia Testnet
#         </a>
#        </li>
#        <li>
#         <a class="dropdown-item" href="https://holesky.etherscan.io" id="A2">
#          Holesky Testnet
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </section>
#   <header class="header border-bottom d-print-none" id="masterHeader">
#    <nav class="navbar navbar-expand-lg navbar-light py-3 py-lg-0">
#     <div class="container-xxl position-relative">
#      <a aria-label="Etherscan" class="navbar-brand" href="/" target="_parent">
#       <img alt="Etherscan Logo" data-img-theme="light" src="/assets/svg/logos/logo-etherscan.svg?v=0.0.5" width="150"/>
#       <img alt="Etherscan Logo" data-img-theme="darkmode" src="/assets/svg/logos/logo-etherscan-light.svg?v=0.0.5" width="150"/>
#      </a>
#      <div class="d-flex align-items-center gap-4">
#       <a class="link-dark d-block d-lg-none" href="/login">
#        <i class="far fa-user-circle me-1">
#        </i>
#        Sign In
#       </a>
#       <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
#        <span class="navbar-toggler-icon">
#        </span>
#       </button>
#      </div>
#      <div class="collapse navbar-collapse justify-content-end" id="navbarSupportedContent">
#       <ul class="navbar-nav gap-1 gap-lg-0 pt-4 pt-lg-0">
#        <li class="nav-item">
#         <a aria-current="page" class="nav-link" href="/" id="LI_default">
#          Home
#         </a>
#        </li>
#        <li class="nav-item dropdown">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_blockchain" role="button">
#          Blockchain
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <a class="dropdown-item" href="/txs" id="LI12">
#            Transactions
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/txsPending" id="LI16">
#            Pending Transactions
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/txsInternal" id="LI14">
#            Contract Internal Transactions
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/txsBeaconDeposit" id="LI22">
#            Beacon Deposits
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/txsBeaconWithdrawal" id="LI_BeaconWithdrawals">
#            Beacon Withdrawals
#           </a>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/blocks" id="LI_blocks">
#            View Blocks
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/blocks_forked" id="LI_blocks2">
#            Forked Blocks (Reorgs)
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/uncles" id="LI8">
#            Uncles
#           </a>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/accounts" id="LI_accountall">
#            Top Accounts
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/contractsVerified" id="LI_contract_verified">
#            Verified Contracts
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item dropdown">
#         <a aria-expanded="false" class="nav-link dropdown-toggle active" data-bs-toggle="dropdown" href="javascript:;" id="LI_tokens" role="button">
#          Tokens
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <a class="dropdown-item active" href="/tokens" id="LI21">
#            Top Tokens
#            <span class="small text-muted">
#             (ERC-20)
#            </span>
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/tokentxns" id="LI1">
#            Token Transfers
#            <span class="small text-muted">
#             (ERC-20)
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item dropdown">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_Nfts" role="button">
#          NFTs
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <a class="dropdown-item" href="/nft-top-contracts" id="LI63">
#            Top NFTs
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/nft-top-mints" id="LI67">
#            Top Mints
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/nft-trades" id="LI64">
#            Latest Trades
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/nft-transfers" id="LI65">
#            Latest Transfers
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/nft-latest-mints" id="LI66">
#            Latest Mints
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item dropdown">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_resources" role="button">
#          Resources
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <a class="dropdown-item" href="/charts" id="LI_charts2">
#            Charts And Stats
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/topstat" id="LI_topstat">
#            Top Statistics
#           </a>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/directory" id="LI62">
#            Directory
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://info.etherscan.com/newsletters/" id="LI60">
#            Newsletter
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://info.etherscan.com/" id="LI61">
#            Knowledge Base
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item dropdown">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="li_developers" role="button">
#          Developers
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <a class="dropdown-item" href="/apis" id="LI5">
#            API Plans
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://docs.etherscan.io/" id="LI6" target="_blank">
#            API Documentation
#           </a>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/code-reader" id="A1">
#            Code Reader
#            <span class="badge border bg-light text-muted">
#             Beta
#            </span>
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/verifyContract" id="LI17">
#            Verify Contract
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/find-similar-contracts" id="LI55">
#            Similar Contract Search
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/searchcontract" id="LI53">
#            Smart Contract Search
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/contractdiffchecker" id="LI54">
#            Contract Diff Checker
#           </a>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/vyper" id="LI27">
#            Vyper Online Compiler
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/opcode-tool" id="LI24">
#            Bytecode to Opcode
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/pushTx" id="LI10">
#            Broadcast Transaction
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item dropdown position-initial">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="javascript:;" id="LI_services2" role="button">
#          More
#         </a>
#         <div class="dropdown-menu dropdown-menu-border dropdown-menu-mega">
#          <div class="row">
#           <div class="col-lg order-last order-lg-first">
#            <div class="d-flex flex-column bg-light h-100 rounded-3 p-5">
#             <div>
#              <h6>
#               Tools &amp; Services
#              </h6>
#              <p>
#               Discover more of Etherscan's tools and services in one place.
#              </p>
#             </div>
#             <div class="mt-auto">
#              <p class="text-muted mb-2">
#               Sponsored
#              </p>
#              <a href="https://chat.blockscan.com" target="_blank">
#               <img alt="" data-img-theme="light" src="/images/svg/blockscan-logo-light.svg?v=0.0.5" width="140">
#                <img alt="" data-img-theme="dim" src="/images/svg/blockscan-logo-dark.svg?v=0.0.5" width="140">
#                 <img alt="" data-img-theme="dark" src="/images/svg/blockscan-logo-dark.svg?v=0.0.5" width="140">
#                 </img>
#                </img>
#               </img>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="col-sm py-5">
#            <h6 class="px-3 mb-3">
#             Tools
#            </h6>
#            <ul class="list-unstyled">
#             <li>
#              <a class="dropdown-item" href="/unitconverter" id="LI50">
#               <i class="far fa-arrows-rotate dropdown-item-icon fa-fw me-1">
#               </i>
#               Unit Converter
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/exportData" id="LI51">
#               <i class="far fa-download fa-fw me-1">
#               </i>
#               CSV Export
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/balancecheck-tool" id="LI52">
#               <i class="far fa-file-invoice-dollar fa-fw me-1">
#               </i>
#               Account Balance Checker
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-sm py-5">
#            <h6 class="px-3 mb-3">
#             Explore
#            </h6>
#            <ul class="list-unstyled">
#             <li>
#              <a class="dropdown-item" href="/gastracker" id="LI19">
#               <i class="far fa-gas-pump dropdown-item-icon fa-fw me-1">
#               </i>
#               Gas Tracker
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/dex" id="LI4">
#               <i class="far fa-arrow-right-arrow-left dropdown-item-icon fa-fw me-1">
#               </i>
#               DEX Tracker
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/nodetracker" id="LI46">
#               <i class="far fa-server dropdown-item-icon fa-fw me-1">
#               </i>
#               Node Tracker
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/labelcloud" id="LI41">
#               <i class="far fa-signs-post dropdown-item-icon fa-fw me-1">
#               </i>
#               Label Cloud
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/name-lookup" id="LI26">
#               <i class="far fa-magnifying-glass-chart dropdown-item-icon fa-fw me-1">
#               </i>
#               Domain Name Lookup
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-sm py-5">
#            <h6 class="px-3 mb-3">
#             Services
#            </h6>
#            <ul class="list-unstyled">
#             <li>
#              <a class="dropdown-item" href="/tokenapprovalchecker" id="LI49">
#               <i class="far fa-shield-keyhole dropdown-item-icon fa-fw me-1">
#               </i>
#               Token Approvals
#               <span class="badge border bg-light text-muted">
#                Beta
#               </span>
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/verifiedSignatures" id="LI29">
#               <i class="far fa-signature-lock dropdown-item-icon fa-fw me-1">
#               </i>
#               Verified Signature
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/idm">
#               <i class="far fa-message-lines dropdown-item-icon fa-fw me-1">
#               </i>
#               Input Data Messages (IDM)
#               <span class="badge border bg-light text-muted">
#                Beta
#               </span>
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="/advanced-filter" id="LI31">
#               <i class="far fa-filters dropdown-item-icon fa-fw me-1">
#               </i>
#               Advanced Filter
#               <span class="badge border bg-light text-muted">
#                Beta
#               </span>
#              </a>
#             </li>
#             <li>
#              <a class="dropdown-item" href="https://chat.blockscan.com" target="_blank">
#               <i class="far fa-messages dropdown-item-icon fa-fw me-1">
#               </i>
#               Blockscan Chat
#               <i class="far fa-arrow-up-right-from-square text-muted ms-1">
#               </i>
#               <span class="badge border bg-light text-muted">
#                Beta
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="nav-item dropdown d-block d-lg-none">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" role="button">
#          Explorers
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <a class="dropdown-item active active" href="https://etherscan.io" id="LI_Mainnet_1">
#            Ethereum Mainnet
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://cn.etherscan.com/?lang=zh-CN" id="LI_Mainnet_CN_1">
#            Ethereum Mainnet
#            <span class="badge border bg-light text-dark ms-1">
#             CN
#            </span>
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://beaconscan.com/" id="LI77">
#            Beaconscan
#            <span class="badge border bg-light text-dark ms-1">
#             ETH2
#            </span>
#           </a>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://goerli.etherscan.io" id="LI78">
#            Goerli Testnet
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://sepolia.etherscan.io" id="LI79">
#            Sepolia Testnet
#           </a>
#          </li>
#          <li>
#           <a class="dropdown-item" href="https://holesky.etherscan.io" id="A4">
#            Holesky Testnet
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item dropdown d-block d-lg-none">
#         <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" role="button">
#          Appearance &amp; Settings
#         </a>
#         <ul class="dropdown-menu dropdown-menu-border" style="min-width: 14rem;">
#          <li>
#           <button class="dropdown-item theme-btn active" data-bs-theme-value="light" onclick="setThemeMode('light');" type="button">
#            <i class="far fa-sun-bright fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-sun-bright">
#            </i>
#            Light
#           </button>
#          </li>
#          <li>
#           <button class="dropdown-item theme-btn" data-bs-theme-value="dim" onclick="setThemeMode('dim');" type="button">
#            <i class="far fa-moon-stars fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon-stars">
#            </i>
#            Dim
#           </button>
#          </li>
#          <li>
#           <button class="dropdown-item theme-btn" data-bs-theme-value="dark" onclick="setThemeMode('dark');" type="button">
#            <i class="far fa-moon-stars fa-fw dropdown-item-icon theme-icon me-1" data-href="#fa-moon">
#            </i>
#            Dark
#           </button>
#          </li>
#          <li>
#           <hr class="dropdown-divider"/>
#          </li>
#          <li>
#           <a class="dropdown-item" href="/settings">
#            <i class="far fa-gear fa-fw dropdown-item-icon me-1">
#            </i>
#            Site Settings
#            <i class="far fa-arrow-right ms-1">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="nav-item align-self-center d-none d-lg-block">
#         <span class="text-secondary">
#          |
#         </span>
#        </li>
#        <li class="nav-item d-none d-lg-block">
#         <a class="nav-link" href="/login">
#          <i class="far fa-user-circle me-1">
#          </i>
#          Sign In
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <main class="main-content" id="content" role="main">
#    <input id="hdnAgeText" name="hdnAgeText" type="hidden" value="Age"/>
#    <input id="hdnDateTimeText" name="hdnDateTimeText" type="hidden" value="Date Time (UTC)"/>
#    <input id="hdnAgeTitle" name="hdnAgeTitle" type="hidden" value="Click to show Age Format"/>
#    <input id="hdnDateTimeTitle" name="hdnDateTimeTitle" type="hidden" value="Click to show Datetime Format"/>
#    <input id="hdnTxnText" name="hdnTxnText" type="hidden" value="Txn Fee"/>
#    <input id="hdnGasPriceText" name="hdnGasPriceText" type="hidden" value="Gas Price"/>
#    <input id="hdnTxnFeeTitle" name="hdnTxnFeeTitle" type="hidden" value="(Gas Price * Gas Used by Txns) in Ether"/>
#    <input id="hdnGasPriceTitle" name="hdnGasPriceTitle" type="hidden" value="Gas Price in Gwei"/>
#    <section class="container-xxl">
#     <div class="d-flex flex-wrap justify-content-between align-items-center border-bottom gap-3 py-5">
#      <div class="d-flex flex-wrap align-items-center gap-1">
#       <h1 class="h5 mb-0">
#        Token Tracker
#        <span id="ContentPlaceHolder1_erc20InfoLink">
#         (ERC-20)
#        </span>
#       </h1>
#       <span class="text-muted text-break">
#       </span>
#      </div>
#     </div>
#    </section>
#    <section class="container-xxl pt-5 pb-12">
#     <div class="card" id="ContentPlaceHolder1_divERC20Tokens">
#      <div class="card-body d-flex flex-wrap align-items-center justify-content-between gap-3">
#       <p class="mb-0">
#        <span class="text-dark">
#         A total of
#         <strong>
#          1,239
#         </strong>
#         Token Contracts found
#        </span>
#        <span class="d-block small">
#        </span>
#       </p>
#       <div>
#        <div class="dropdown order-md-2">
#         <button aria-expanded="false" class="btn btn-sm btn-secondary" data-bs-toggle="dropdown" id="erc20TokenSearchButton" type="button">
#          <i class="far fa-search">
#          </i>
#         </button>
#         <div aria-labelledby="erc20TokenSearchButton" class="search-panel-container auto-search-max-height dropdown-menu dropdown-menu-sm-end" style="min-width: 10rem">
#          <form action="/tokens" autocomplete="off" method="get" spellcheck="false">
#           <div class="input-group" style="min-width: 20rem;">
#            <input class="form-control py-2" id="erc20TokenSearchInput" name="q" onkeyup="handleTokenSearch(this);" placeholder="Search for Token Name or Address" type="search" value=""/>
#            <button class="btn btn-primary" type="submit">
#             Find
#            </button>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="table-responsive">
#       <div id="ContentPlaceHolder1_tblErc20Tokens">
#        <table class="table table-hover mb-0">
#         <thead class="align-middle text-nowrap">
#          <tr>
#           <th class="text-center text-muted" scope="col" width="20">
#            #
#           </th>
#           <th scope="col">
#            Token
#           </th>
#           <th scope="col">
#            <a data-bs-title="Click for descending sort" data-bs-toggle="tooltip" data-bs-trigger="hover" href="/tokens?sort=price_usd&amp;order=desc">
#             Price
#            </a>
#           </th>
#           <th scope="col">
#            <a data-bs-title="Click for descending sort" data-bs-toggle="tooltip" data-bs-trigger="hover" href="/tokens?sort=percent_change_24h&amp;order=desc">
#             Change (%)
#            </a>
#           </th>
#           <th scope="col">
#            <a data-bs-title="Click for descending sort" data-bs-toggle="tooltip" data-bs-trigger="hover" href="/tokens?sort=24h_volume_usd&amp;order=desc">
#             Volume (24H)
#            </a>
#           </th>
#           <th scope="col">
#            <i class="far fa-arrow-down-wide-short small text-secondary me-0.5">
#            </i>
#            <a data-bs-title="Sorted in descending order, Click for ascending sort" data-bs-toggle="tooltip" data-bs-trigger="hover" href="/tokens?sort=marketcap&amp;order=asc">
#             Circulating Market Cap
#            </a>
#            <i class="far fa-question-circle text-muted" data-bs-title="Calculated by multiplying the number of tokens in circulating supply across all chains with the current market price per token." data-bs-toggle="tooltip" data-bs-trigger="hover">
#            </i>
#           </th>
#           <th scope="col">
#            On-Chain Market Cap
#            <i class="far fa-question-circle text-muted" data-bs-title="Calculated by multiplying the token's Total Supply on Ethereum with the current market price per token." data-bs-toggle="tooltip" data-bs-trigger="hover">
#            </i>
#           </th>
#           <th scope="col">
#            <a data-bs-title="Click for descending sort" data-bs-toggle="tooltip" data-bs-trigger="hover" href="/tokens?sort=holders&amp;order=desc">
#             Holders
#            </a>
#           </th>
#          </tr>
#         </thead>
#         <tbody class="align-middle text-nowrap">
#          <tr>
#           <td>
#            1
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0xdac17f958d2ee523a2206206994597c13d831ec7">
#             <img class="rounded-circle" height="24" src="/token/images/tethernew_32.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               Tether USD
#              </div>
#              <span class="text-muted">
#               (USDT)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$1.00" data-bs-toggle="tooltip">
#             $1.00
#            </div>
#            <div class="text-muted small">
#             0.000611 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-success text-nowrap">
#             <i class="fas fa-caret-up me-1">
#             </i>
#             0.01%
#            </span>
#           </td>
#           <td>
#            $16,279,573,188.00
#           </td>
#           <td>
#            $83,369,918,594.00
#           </td>
#           <td>
#            $39,823,119,845.00
#           </td>
#           <td>
#            <div>
#             4,580,187
#            </div>
#            <div class="text-danger small d-inline" data-bs-title="A -0.094% decrease in Token holders from previous day count of 4584483" data-bs-toggle="tooltip">
#             -0.094%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52">
#             <img class="rounded-circle" height="24" src="/token/images/bnb_28_2.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               BNB
#              </div>
#              <span class="text-muted">
#               (BNB)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$212.75073265" data-bs-toggle="tooltip">
#             $212.7507
#            </div>
#            <div class="text-muted small">
#             0.129889 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-success text-nowrap">
#             <i class="fas fa-caret-up me-1">
#             </i>
#             0.08%
#            </span>
#           </td>
#           <td>
#            $332,364,359.00
#           </td>
#           <td>
#            $32,730,872,926.00
#           </td>
#           <td>
#            $3,527,304,388.67
#           </td>
#           <td>
#            <div>
#             285,796
#            </div>
#            <div class="text-success small d-inline" data-bs-title="A 0.009% increase in Token holders from previous day count of 285770" data-bs-toggle="tooltip">
#             0.009%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            3
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48">
#             <img class="rounded-circle" height="24" src="/token/images/centre-usdc_28.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               USDC
#              </div>
#              <span class="text-muted">
#               (USDC)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$1.00" data-bs-toggle="tooltip">
#             $1.00
#            </div>
#            <div class="text-muted small">
#             0.000611 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-success text-nowrap">
#             <i class="fas fa-caret-up me-1">
#             </i>
#             0.07%
#            </span>
#           </td>
#           <td>
#            $3,879,695,290.00
#           </td>
#           <td>
#            $25,255,348,953.00
#           </td>
#           <td>
#            $46,602,430,840.00
#           </td>
#           <td>
#            <div>
#             1,790,688
#            </div>
#            <div class="text-danger small d-inline" data-bs-title="A -0.046% decrease in Token holders from previous day count of 1791518" data-bs-toggle="tooltip">
#             -0.046%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            4
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0xae7ab96520de3a18e5e111b5eaab095312d7fe84">
#             <img class="rounded-circle" height="24" src="/token/images/lido-steth_32.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               stETH
#              </div>
#              <span class="text-muted">
#               (stETH)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$1,640.60" data-bs-toggle="tooltip">
#             $1,640.60
#            </div>
#            <div class="text-muted small">
#             1.001619 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-danger text-nowrap">
#             <i class="fas fa-caret-down me-1">
#             </i>
#             -0.42%
#            </span>
#           </td>
#           <td>
#            $5,560,941.00
#           </td>
#           <td>
#            $14,459,518,712.00
#           </td>
#           <td>
#            $3,041,030,925.40
#           </td>
#           <td>
#            <div>
#             270,064
#            </div>
#            <div class="text-success small d-inline" data-bs-title="A 0.064% increase in Token holders from previous day count of 269890" data-bs-toggle="tooltip">
#             0.064%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            5
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0x50327c6c5a14dcade707abad2e27eb517df87ab5">
#             <img class="rounded-circle" height="24" src="/token/images/trontrx_32.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               TRON
#              </div>
#              <span class="text-muted">
#               (TRX)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$0.088834" data-bs-toggle="tooltip">
#             $0.0888
#            </div>
#            <div class="text-muted small">
#             0.000054 ETH
#            </div>
#           </td>
#           <td>
#            --
#           </td>
#           <td>
#            $224,534,429.00
#           </td>
#           <td>
#            $7,904,153,443.00
#           </td>
#           <td>
#            $231.06
#           </td>
#           <td>
#            <div>
#             2,208
#            </div>
#            <div class="text-success small d-inline" data-bs-title="A 0.317% increase in Token holders from previous day count of 2201" data-bs-toggle="tooltip">
#             0.317%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            6
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0x582d872a1b094fc48f5de31d3b73f2d9be47def1">
#             <img class="rounded-circle" height="24" src="/token/images/theopennetwork_32.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               Wrapped TON Coin
#              </div>
#              <span class="text-muted">
#               (TONCOIN)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$2.09" data-bs-toggle="tooltip">
#             $2.09
#            </div>
#            <div class="text-muted small">
#             0.001276 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-success text-nowrap">
#             <i class="fas fa-caret-up me-1">
#             </i>
#             4.32%
#            </span>
#           </td>
#           <td>
#            $16,895,926.00
#           </td>
#           <td>
#            $7,200,646,823.00
#           </td>
#           <td>
#            $15,354,617.63
#           </td>
#           <td>
#            <div>
#             7,677
#            </div>
#            <div class="small d-inline" data-bs-title="No change in Token holders from previous day" data-bs-toggle="tooltip">
#             0.000%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            7
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0x3883f5e181fccaf8410fa61e12b59bad963fb645">
#             <img class="rounded-circle" height="24" src="/token/images/theta_28.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               Theta Token
#              </div>
#              <span class="text-muted">
#               (THETA)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$5.2666954" data-bs-toggle="tooltip">
#             $5.2667
#            </div>
#            <div class="text-muted small">
#             0.003215 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-danger text-nowrap">
#             <i class="fas fa-caret-down me-1">
#             </i>
#             -9.81%
#            </span>
#           </td>
#           <td>
#            $271,444,395.00
#           </td>
#           <td>
#            $5,266,695,404.00
#           </td>
#           <td>
#            $5,266,695,404.45
#           </td>
#           <td>
#            <div>
#             28,402
#            </div>
#            <div class="small d-inline" data-bs-title="No change in Token holders from previous day" data-bs-toggle="tooltip">
#             0.000%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            8
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0">
#             <img class="rounded-circle" height="24" src="/token/images/polygonmatic_new_32.png" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               Matic Token
#              </div>
#              <span class="text-muted">
#               (MATIC)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$0.56335336" data-bs-toggle="tooltip">
#             $0.5634
#            </div>
#            <div class="text-muted small">
#             0.000344 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-danger text-nowrap">
#             <i class="fas fa-caret-down me-1">
#             </i>
#             -3.46%
#            </span>
#           </td>
#           <td>
#            $301,112,205.00
#           </td>
#           <td>
#            $5,239,075,310.00
#           </td>
#           <td>
#            $5,633,533,626.77
#           </td>
#           <td>
#            <div>
#             629,170
#            </div>
#            <div class="text-success small d-inline" data-bs-title="A 0.004% increase in Token holders from previous day count of 629147" data-bs-toggle="tooltip">
#             0.004%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            9
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599">
#             <img class="rounded-circle" height="24" src="/token/images/wbtc_28.png?v=1" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               Wrapped BTC
#              </div>
#              <span class="text-muted">
#               (WBTC)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$27,671.00" data-bs-toggle="tooltip">
#             $27,671.00
#            </div>
#            <div class="text-muted small">
#             16.893700 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-success text-nowrap">
#             <i class="fas fa-caret-up me-1">
#             </i>
#             0.46%
#            </span>
#           </td>
#           <td>
#            $83,442,076.00
#           </td>
#           <td>
#            $4,503,832,873.00
#           </td>
#           <td>
#            $7,244,655,194.00
#           </td>
#           <td>
#            <div>
#             77,850
#            </div>
#            <div class="text-success small d-inline" data-bs-title="A 0.041% increase in Token holders from previous day count of 77818" data-bs-toggle="tooltip">
#             0.041%
#            </div>
#           </td>
#          </tr>
#          <tr>
#           <td>
#            10
#           </td>
#           <td>
#            <a class="d-flex align-items-center gap-1 link-dark" href="/token/0x514910771af9ca656af840dff83e8264ecf986ca">
#             <img class="rounded-circle" height="24" src="/token/images/chainlinktoken_32.png?v=6" width="24"/>
#             <div class="d-flex gap-1">
#              <div class="hash-tag text-truncate fw-medium">
#               ChainLink Token
#              </div>
#              <span class="text-muted">
#               (LINK)
#              </span>
#             </div>
#            </a>
#           </td>
#           <td>
#            <div class="d-inline" data-bs-title="$7.71" data-bs-toggle="tooltip">
#             $7.71
#            </div>
#            <div class="text-muted small">
#             0.004707 ETH
#            </div>
#           </td>
#           <td>
#            <span class="text-success text-nowrap">
#             <i class="fas fa-caret-up me-1">
#             </i>
#             1.78%
#            </span>
#           </td>
#           <td>
#            $273,603,042.00
#           </td>
#           <td>
#            $4,286,153,187.00
#           </td>
#           <td>
#            $7,710,000,000.00
#           </td>
#           <td>
#            <div>
#             679,837
#            </div>
# ...
#         }
#
#         function saveCopyAddressConfirmationSetting(ignoreCopyConfirmation) {
#             const copyAddressConfirmationSetting = {
#                 ignoreCopyConfirmation: ignoreCopyConfirmation,
#                 expiresOn: Date.now() + 1000 * 60 * 60 * 24 * 30
#             };
#             localStorage.setItem("copyAddressConfirmationSetting", JSON.stringify(copyAddressConfirmationSetting));
#         }
#
#         function getCopyAddressConfirmationSetting() {
#             try {
#                 const settings = localStorage.getItem("copyAddressConfirmationSetting");
#                 if (settings) {
#                     const copyAddressConfirmationSetting = JSON.parse(settings);
#
#                     return copyAddressConfirmationSetting.ignoreCopyConfirmation && copyAddressConfirmationSetting.expiresOn > Date.now();
#                 }
#                 else {
#                     return false;
#                 }
#             } catch (e) {
#                 console.log(e);
#                 return false;
#             }
#         }
#   </script>
#   <script src="/assets/vendor/datatables/datatables.min.js?v=23.9.4.0" type="text/javascript">
#   </script>
#   <script src="/assets/js/custom/datatables/plugins/custompagination.js?v=23.9.4.0" type="text/javascript">
#   </script>
#   <script>
#    const resetSortDictionary = {};
#         const resetPageDictionary = {};
#         const visitedTabDictionary = {};
#         const queryStringDictionary = {};
#         const currentLengthDictionary = {};
#         let currentTab = 0;
#         const refreshToDefaultDictionary = {};
#         const defaultLength = 50;
#         const defaultSort = {};
#         const totalPage = 0;
#         const isLoggedIn = false;
#
#         const sortAscIcon = `<i class="far fa-arrow-up-wide-short small text-secondary me-1"></i>`;
#         const sortDescIcon = `<i class="far fa-arrow-down-wide-short small text-secondary me-1"></i>`;
#
#         // Document Ready
#         $(document).ready(function () {
#             if ($("#ContentPlaceHolder1_divTokenByLabels")[0]) {
#                 renderDataTable();
#                 var currentTableId = `table-subcatid-${currentTab}`;
#                 $(`#${currentTableId}`).DataTable().ajax.reload();
#             }
#         });
#
#         function renderDataTable() {
#             visitedTabDictionary["tab-" + currentTab] = true;
#
#             let hideTableFooterCss = "";
#             if (isLoggedIn == false) {
#                 hideTableFooterCss = "d-none";
#             }
#             const config = {
#                 dom:
#                     `<"d-flex flex-wrap align-items-center justify-content-between gap-3 p-4 text-dark"ip>
#                     <"custom-datatables-processing"r>
#                     t
#                     <"${hideTableFooterCss} card-footer d-flex flex-wrap justify-content-between align-items-center gap-3"<"d-flex align-items-center gap-2"l>p>`,
#                 language: {
#                     emptyTable: "No Token Contracts found for the address.",
#                     info: `A total of <span class="fw-medium">_MAX_</span> Token Contracts found`,
#                     infoEmpty: `A total of <span class="fw-medium">0</span> Token Contracts found`,
#                     lengthMenu: "Show rows: _MENU_",
#                     processing: `<!-- Spinner --><div id="overlay" class="text-center py-10 "><div class="spinner-border text-primary" role="status"><span class="visually-hidden">Loading...</span></div><div class="small text-muted mt-1">Loading</div></div><!-- End Spinner -->`
#                 },
#                 oLanguage: {
#                     oPaginate: {
#                         next: `<i class="fas fa-chevron-right small"></i>`,
#                         previous: `<i class="fas fa-chevron-left small"></i>`
#                     }
#                 },
#                 columns: [
#                     { data: "number" },
#                     { data: "contractAddress" },
#                     { data: "tokenName" },
#                     { data: "marketCap" },
#                     { data: "holders" },
#                     { data: "website" }
#                 ],
#                 columnDefs: [
#                     { orderable: true, targets: 2, orderSequence: ["asc", "desc", "reset"] },
#                     { orderable: true, targets: 3, orderSequence: ["desc", "asc"] },
#                     { orderable: true, targets: 4, orderSequence: ["desc", "asc", "reset"] },
#                     { orderable: false, targets: '_all' }
#                 ],
#                 drawCallback: function (settings) {
#                     const tableId = this.attr("id");
#                     const tableApi = this.api();
#                     const json = tableApi.ajax.json();
#                     if (!json) {
#                         var urlParams = new URLSearchParams(window.location.search);
#                         var existLength = urlParams.get('size');
#                         if (existLength) {
#                             tableApi.page.len(existLength);
#                             currentLengthDictionary[tableId] = parseInt(existLength)
#
#                             var existStart = urlParams.get('start');
#                             if (!existStart) {
#                                 existStart = 0
#                             }
#                             currentPage = Math.floor(existStart / existLength);
#                             tableApi.page(currentPage);
#                         }
#
#                         var existCol = urlParams.get('col');
#                         var existOrder = urlParams.get('order');
#                         if (existCol && existOrder) {
#                             tableApi.order([parseInt(existCol), existOrder]);
#                         }
#
#                         return;
#                     } else {
#                         if (refreshToDefaultDictionary[tableId]) {
#                             refreshToDefaultDictionary[tableId] = false;
#                             tableApi.page.len(defaultLength);
#                             tableApi.order([defaultSort["column"], defaultSort["dir"]]);
#                         }
#
#                         if (resetSortDictionary[tableId]) {
#                             tableApi.order([defaultSort["column"], defaultSort["dir"]]);
#                         }
#
#                         if (resetPageDictionary[tableId]) {
#                             tableApi.page(0);
#                             resetPageDictionary[tableId] = false;
#                         }
#                     }
#
#                     if (isLoggedIn == true) {
#                         const currentOrder = tableApi.order()[0];
#                         const isDefaultSorting = currentOrder[0] == defaultSort["column"] && currentOrder[1] == defaultSort["dir"];
#                         updateSortingHeaders(tableId, isDefaultSorting);
#                     }
#
#                     const subCatId = currentTab
#                     const pageInfo = tableApi.page.info();
#                     if (pageInfo.length) {
#                         queryStringDictionary["length_" + subCatId] = pageInfo.length;
#                     }
#                     if (pageInfo.start !== undefined) {
#                         queryStringDictionary["start_" + subCatId] = pageInfo.start;
#                     }
#
#                     const orderInfo = tableApi.order();
#                     queryStringDictionary["col_" + subCatId] = orderInfo[0][0];
#                     queryStringDictionary["order_" + subCatId] = orderInfo[0][1];
#
#                     updateUrl(subCatId);
#                     updateTableComponents();
#                     $(`[data-bs-toggle="tooltip"]`).tooltip();
#                     HSCore.components.HSClipboard.init('.js-clipboard');
#                 },
#                 ajax: {
#                     type: "POST",
#                     contentType: "application/json",
#                     url: "/tokens.aspx/GetTokensBySubLabel",
#                     dataType: 'json',
#                     dataFilter: function (res) {
#                         var parsed = JSON.parse(res);
#                         var morp = parsed.d;
#                         return JSON.stringify(morp);
#                     },
#                     data: function (d, settings) {
#                         var labelModel = generateLabelModel();
#                         var tableId = settings.nTable.getAttribute("id");
#
#                         if (refreshToDefaultDictionary[tableId]) {
#                             d.length = defaultLength;
#                             d.order[0] = defaultSort;
#                         }
#
#                         if (currentLengthDictionary[tableId] != d.length) {
#                             if (currentLengthDictionary[tableId] != undefined) {
#                                 d.start = 0;
#                                 resetPageDictionary[tableId] = true;
#                             }
#                             currentLengthDictionary[tableId] = d.length;
#                         }
#
#                         if ((d.order[0] && d.order[0].dir === "reset")) {
#                             d.order[0] = defaultSort;
#                             resetSortDictionary[tableId] = true;
#                         }
#                         else {
#                             resetSortDictionary[tableId] = false;
#                         }
#
#                         return JSON.stringify({ dataTableModel: d, labelModel: labelModel });
#                     }
#                 },
#                 autoWidth: false,
#                 serverSide: true,
#                 processing: true,
#                 searching: false,
#                 pagingType: 'custompagination',
#                 paging: false,
#                 ordering: false,
#                 order: [],
#                 pageLength: 50
#             };
#
#
#         }
#
#         function updateSortingHeaders(tableId, isDefaultSorting) {
#             var hasAscSort = false;
#             var hasDescSort = false;
#             $(`#${tableId} th.sorting_asc`).each(function () {
#                 $(this).removeClass("sorting_asc");
#                 var headerText = $(this).text();
#                 headerText = `<a href="javascript:void(0)">${headerText}</a>`;
#                 $(this).html(`${sortAscIcon}${headerText}`);
#                 hasAscSort = true;
#             });
#             $(`#${tableId} th.sorting_desc`).each(function () {
#                 $(this).removeClass("sorting_desc");
#                 var headerText = $(this).text();
#                 headerText = `<a href="javascript:void(0)">${headerText}</a>`;
#                 $(this).html(`${sortDescIcon}${headerText}`);
#                 hasDescSort = true;
#             });
#             $(`#${tableId} th.sorting`).each(function () {
#                 $(this).removeClass("sorting");
#                 var headerText = $(this).text();
#                 headerText = `<a href="javascript:void(0)">${headerText}</a>`;
#                 $(this).html(headerText);
#             });
#
#             if (hasAscSort === false && hasDescSort === false && isDefaultSorting) {
#                 $(`#${tableId} th.defaultSortingCol`).each(function () {
#                     $(this).removeClass("sorting_desc");
#                     var headerText = $(this).text();
#                     headerText = `<a href="javascript:void(0)">${headerText}</a>`;
#                     $(this).html(`${sortDescIcon}${headerText}`);
#                 });
#             }
#         }
#
#         function updateTableComponents() {
#             $(".dataTables_info").addClass("p-0");
#             $(".dataTables_length").find("label").addClass("d-flex align-items-center gap-2 text-muted");
#             $(".dataTables_length").find("select").removeAttr("class").addClass("form-select form-select-sm w-auto");
#             $(".dataTables_length").find("select").on("change", function () {
#                 window.scrollTo(0, 0);
#             });
#         }
#
#         function generateLabelModel() {
#             const id = $('#hdnId').val();
#             const label = $('#ContentPlaceHolder1_hdnLabelFilter').val();
#
#             return { id: id, label: label, subCategoryId: currentTab };
#         }
#
#         function activeTab(selectedTab) {
#             const subCategoryId = $(selectedTab).data("sub-category-id");
#             currentTab = subCategoryId;
#
#             if (!visitedTabDictionary["tab-" + subCategoryId]) {
#                 visitedTabDictionary["tab-" + subCategoryId] = true;
#                 $('#table-subcatid-' + subCategoryId).DataTable().ajax.reload();
#             }
#
#             updateUrl(subCategoryId)
#         }
#
#         function updateUrl(subCatId) {
#             let queryString = `subcatid=${subCatId}`;
#
#             let length = queryStringDictionary["length_" + subCatId];
#             if (length) {
#                 if (length < 0) {
#                     length = 7;
#                 }
#                 queryString += `&size=${length}`;
#             }
#
#             const start = queryStringDictionary["start_" + subCatId];
#             if (start !== undefined) {
#                 queryString += `&start=${start}`;
#             }
#
#             const col = queryStringDictionary["col_" + subCatId];
#             if (col !== undefined) {
#                 queryString += `&col=${col}`;
#             }
#
#             const order = queryStringDictionary["order_" + subCatId];
#             if (order !== undefined) {
#                 queryString += `&order=${order}`;
#             }
#
#             const baseUrl = window.location.href.split("?")[0];
#             history.pushState("", document.title, `${baseUrl}?${queryString}`);
#         }
#
#         function handleTokenSearch(el) {
#             const self = $(el);
#             if (!self || self.val() == "") {
#                 $("#hdnSearchText").val("");
#             }
#         }
#   </script>
#   <script>
#    (function () {
#             // INPUT FOCUS (DROPDOWN)
#             // =======================================================
#             document.getElementById("erc20TokenSearchButton").addEventListener("click", () => {
#                 if (!((('ontouchstart' in window)
#                     || (navigator.maxTouchPoints > 0)
#                     || (navigator.msMaxTouchPoints > 0))
#                     && window.innerWidth <= 991)) {
#                     document.getElementById("erc20TokenSearchInput").focus();
#                 }
#             });
#             let searchAttributes = {
#                 'name': 'title',
#                 'img': 'img',
#                 'rate': 'rate',
#                 'address': 'address',
#                 'link': 'link',
#                 'group': 'group',
#                 'groupid': 'groupid',
#                 'website': 'website',
#                 'ps': 'ps',
#                 'is_verified': 'is_checked'
#             }
#             etherSearchInit({
#                 id: 'erc20TokenSearchInput',
#                 isMainPanel: false,
#                 classResultWrapper: 'mt-12',
#                 attributes: searchAttributes
#             });
#         })();
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'81157a503b1803f1',t:'MTY5NjUwNjk0OS4zMjAwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#  </body>
# </html>

# %%
# Print all the text in the webpage
print(soup.get_text())
# Out:
# 	Token Tracker | Etherscan
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ETH Price: $1,637.95 (-0.52%) Gas: 6 Gwei
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /
#
#
#
#
#
#
#
#
#
#
#  Light
#
#
#
#
#  Dim
#
#
#
#
#  Dark
#
#
#
#
#
#
#
#  Site Settings
#
#
#
#
#
#
#
#
#
#
#
#
# Ethereum Mainnet
#
#
#
#
# Ethereum Mainnet CN
#
#
#
#
# Beaconscan ETH2
#
#
#
#
#
#
#
# Goerli Testnet
#
#
#
#
# Sepolia Testnet
#
#
#
#
# Holesky Testnet
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Sign In
#
#
#
#
#
#
#
#
#
# Home
#
#
#
# Blockchain
#
#
#
# Transactions
#
#
#
#
# Pending Transactions
#
#
#
#
# Contract Internal Transactions
#
#
#
#
# Beacon Deposits
#
#
#
#
# Beacon Withdrawals
#
#
#
#
#
#
#
# View Blocks
#
#
#
#
# Forked Blocks (Reorgs)
#
#
#
#
# Uncles
#
#
#
#
#
#
#
# Top Accounts
#
#
#
#
# Verified Contracts
#
#
#
#
#
# Tokens
#
#
#
# Top Tokens (ERC-20)
#
#
#
#
# Token Transfers (ERC-20)
#
#
#
#
#
# NFTs
#
#
#
# Top NFTs
#
#
#
#
# Top Mints
#
#
#
#
# Latest Trades
#
#
#
#
# Latest Transfers
#
#
#
#
# Latest Mints
#
#
#
#
#
# Resources
#
#
#
# Charts And Stats
#
#
#
#
# Top Statistics
#
#
#
#
#
#
#
# Directory
#
#
#
#
# Newsletter
#
#
#
#
# Knowledge Base
#
#
#
#
#
# Developers
#
#
#
# API Plans
#
#
#
#
# API Documentation
#
#
#
#
#
#
#
# Code Reader Beta
#
#
#
#
# Verify Contract
#
#
#
#
# Similar Contract Search
#
#
#
#
# Smart Contract Search
#
#
#
#
# Contract Diff Checker
#
#
#
#
#
#
#
# Vyper Online Compiler
#
#
#
#
# Bytecode to Opcode
#
#
#
#
# Broadcast Transaction
#
#
#
#
#
# More
#
#
#
#
#
# Tools & Services
# Discover more of Etherscan's tools and services in one place.
#
#
# Sponsored
#
#
#
#
#
#
#
#
#
# Tools
#
#
#
# Unit Converter
#
#
#
#
# CSV Export
#
#
#
#
# Account Balance Checker
#
#
#
#
#
# Explore
#
#
#
# Gas Tracker
#
#
#
#
# DEX Tracker
#
#
#
#
# Node Tracker
#
#
#
#
# Label Cloud
#
#
#
#
# Domain Name Lookup
#
#
#
#
#
# Services
#
#
#
# Token Approvals Beta
#
#
#
#
# Verified Signature
#
#
#
#
# Input Data Messages (IDM) Beta
#
#
#
#
# Advanced Filter Beta
#
#
#
#
# Blockscan Chat  Beta
#
#
#
#
#
#
#
#
# Explorers
#
#
#
# Ethereum Mainnet
#
#
#
#
# Ethereum Mainnet CN
#
#
#
#
# Beaconscan ETH2
#
#
#
#
#
#
#
# Goerli Testnet
#
#
#
#
# Sepolia Testnet
#
#
#
#
# Holesky Testnet
#
#
#
#
#
# Appearance & Settings
#
#
#
#  Light
#
#
#
#
#  Dim
#
#
#
#
#  Dark
#
#
#
#
#
#
#
#  Site Settings
#
#
#
#
#
# |
#
#
#
#  Sign In
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Token Tracker
# (ERC-20)
#
#
#
#
#
#
#
#
#
#
#
# A total of 1,239 Token Contracts found
#
#
#
#
#
#
#
#
#
#
#
#
#
# Find
#
#
#
#
#
#
#
#
#
#
#
# #
# Token
#
# Price
#
#
# Change (%)
#
#
# Volume (24H)
#
#
#
#
# Circulating Market Cap
#
#
#
#
# On-Chain Market Cap
#
#
#
# Holders
#
#
#
#
# 1
#
#
# Tether USD
# (USDT)
#
#
# $1.00
#
#
# 0.000611 ETH
#
# 0.01%
#
# $16,279,573,188.00
# $83,369,918,594.00   $39,823,119,845.00   4,580,187
# -0.094%
# 2
#
#
# BNB
# (BNB)
#
#
# $212.7507
#
#
# 0.129889 ETH
#
# 0.08%
#
# $332,364,359.00
# $32,730,872,926.00   $3,527,304,388.67   285,796
# 0.009%
# 3
#
#
# USDC
# (USDC)
#
#
# $1.00
#
#
# 0.000611 ETH
#
# 0.07%
#
# $3,879,695,290.00
# $25,255,348,953.00   $46,602,430,840.00   1,790,688
# -0.046%
# 4
#
#
# stETH
# (stETH)
#
#
# $1,640.60
#
#
# 1.001619 ETH
#
# -0.42%
#
# $5,560,941.00
# $14,459,518,712.00   $3,041,030,925.40   270,064
# 0.064%
# 5
#
#
# TRON
# (TRX)
#
#
# $0.0888
#
#
# 0.000054 ETH
#
# --
#
# $224,534,429.00
# $7,904,153,443.00   $231.06   2,208
# 0.317%
# 6
#
#
# Wrapped TON Coin
# (TONCOIN)
#
#
# $2.09
#
#
# 0.001276 ETH
#
# 4.32%
#
# $16,895,926.00
# $7,200,646,823.00   $15,354,617.63   7,677
# 0.000%
# 7
#
#
# Theta Token
# (THETA)
#
#
# $5.2667
#
#
# 0.003215 ETH
#
# -9.81%
#
# $271,444,395.00
# $5,266,695,404.00   $5,266,695,404.45   28,402
# 0.000%
# 8
#
#
# Matic Token
# (MATIC)
#
#
# $0.5634
#
#
# 0.000344 ETH
#
# -3.46%
#
# $301,112,205.00
# $5,239,075,310.00   $5,633,533,626.77   629,170
# 0.004%
# 9
#
#
# Wrapped BTC
# (WBTC)
#
#
# $27,671.00
#
#
# 16.893700 ETH
#
# 0.46%
#
# $83,442,076.00
# $4,503,832,873.00   $7,244,655,194.00   77,850
# 0.041%
# 10
#
#
# ChainLink Token
# (LINK)
#
#
# $7.71
#
#
# 0.004707 ETH
#
# 1.78%
#
# $273,603,042.00
# $4,286,153,187.00   $7,710,000,000.00   679,837
# 0.020%
# 11
#
#
# SHIBA INU
# (SHIB)
#
#
# $0.00
#
#
# 0.000000 ETH
#
# 0.03%
#
# $63,605,814.00
# $4,256,971,078.00   $7,229,940,957.62   1,344,151
# 0.010%
# 12
#
#
# Dai Stablecoin
# (DAI)
#
#
# $1.001
#
#
# 0.000611 ETH
#
# 0.05%
#
# $100,304,495.00
# $3,825,552,887.00   $9,809,451,981.33   496,640
# -0.010%
# 13
#
#
# Bitfinex LEO Token
# (LEO)
#
#
# $3.79
#
#
# 0.002314 ETH
#
# 1.53%
#
# $355,074.00
# $3,519,235,387.00   $2,501,400,000.00   2,715
# 0.000%
# 14
#
#
# TrueUSD
# (TUSD)
#
#
# $0.9996
#
#
# 0.000610 ETH
#
# 0.04%
#
# $172,835,976.00
# $3,433,625,634.00   $1,137,165,473.05   51,652
# 0.014%
# 15
#
#
# Uniswap
# (UNI)
#
#
# $4.31
#
#
# 0.002631 ETH
#
# -0.31%
#
# $62,360,278.00
# $3,247,043,893.00   $4,310,000,000.00   366,305
# 0.035%
# 16
#
#
# OKB
# (OKB)
#
#
# $42.93
#
#
# 0.026210 ETH
#
# -0.46%
#
# $1,631,572.00
# $2,576,159,427.00   $12,879,000,000.00   50,685
# 0.006%
# 17
#
#
# BUSD
# (BUSD)
#
#
# $1.001
#
#
# 0.000611 ETH
#
# 0.02%
#
# $2,052,507,915.00
# $2,238,214,231.00   $17,592,669,900.81   167,547
# -0.019%
# 18
#
#
# Lido DAO Token
# (LDO)
#
#
# $1.57
#
#
# 0.000959 ETH
#
# -2.59%
#
# $25,611,792.00
# $1,396,878,569.00   $1,570,000,000.00   40,562
# 0.030%
# 19
#
#
# Cronos Coin
# (CRO)
#
#
# $0.0504
#
#
# 0.000031 ETH
#
# 0.27%
#
# $4,402,001.00
# $1,327,024,224.00   $5,037,300,000.00   300,896
# 0.008%
# 20
#
#
# Maker
# (MKR)
#
#
# $1,468.27
#
#
# 0.896408 ETH
#
# 2.94%
#
# $79,250,227.00
# $1,319,095,018.00   $1,435,426,268.37   94,345
# 0.001%
# 21
#
#
# Mantle
# (MNT)
#
#
# $0.4065
#
#
# 0.000248 ETH
#
# -0.33%
#
# $24,281,345.00
# $1,315,152,327.00   $2,527,940,820.40   7,363
# 0.380%
# 22
#
#
# Quant
# (QNT)
#
#
# $87.19
#
#
# 0.053231 ETH
#
# -1.17%
#
# $19,674,500.00
# $1,266,832,393.00   $3,964,267,730.00   145,511
# -0.003%
# 23
#
#
# VeChain
# (VEN)
#
#
# $0.0167
#
#
# 0.000010 ETH
#
# 0.09%
#
# $27,265,862.00
# $1,213,753,211.00   $16,692,034.32   46,198
# 0.000%
# 24
#
#
# Arbitrum
# (ARB)
#
#
# $0.8836
#
#
# 0.000539 ETH
#
# -0.10%
#
# $110,457,446.00
# $1,124,825,365.00   $4,572.76   12,798
# 0.016%
# 25
#
#
# NEAR
# (NEAR)
#
#
# $1.10
#
#
# 0.000672 ETH
#
# 1.43%
#
# $46,323,511.00
# $1,078,334,429.00   $432,191.10   1,281
# 0.000%
# 26
#
#
# Staked Aave
# (stkAAVE)
#
#
# $68.86
#
#
# 0.042040 ETH
#
# 5.70%
#
# $115,049,487.00
# $1,006,086,011.00   $194,851,076.20   20,528
# 0.029%
# 27
#
#
# Rocket Pool ETH
# (rETH)
#
#
# $1,781.23
#
#
# 1.087477 ETH
#
# -0.42%
#
# $2,520,965.00
# $944,379,964.00   $81,135,026.50   18,879
# 0.042%
# 28
#
#
# Graph Token
# (GRT)
#
#
# $0.0859
#
#
# 0.000052 ETH
#
# -1.34%
#
# $24,550,461.00
# $793,426,182.00   $884,378,571.35   142,390
# 0.021%
# 29
#
#
# Decentralized USD
# (USDD)
#
#
# $1.00
#
#
# 0.000611 ETH
#
# 0.12%
#
# $33,255,779.00
# $729,779,001.00   $3,099,947.30   1,054
# 0.000%
# 30
#
#
# Frax
# (FRAX)
#
#
# $0.9971
#
#
# 0.000609 ETH
#
# 0.01%
#
# $5,233,494.00
# $669,456,406.00   $2,645,513,263.59   8,206
# 0.012%
# 31
#
#
# Immutable X
# (IMX)
#
#
# $0.5679
#
#
# 0.000347 ETH
#
# -0.38%
#
# $518,767,987.00
# $662,994,933.00   $1,135,846,000.00   57,083
# 0.054%
# 32
#
#
# Synthetix Network Token
# (SNX)
#
#
# $2.02
#
#
# 0.001233 ETH
#
# -0.16%
#
# $28,060,560.00
# $659,971,475.00   $489,888,531.50   94,738
# 0.006%
# 33
#
#
# Render Token
# (RNDR)
#
#
# $1.73
#
#
# 0.001056 ETH
#
# 2.93%
#
# $28,556,770.00
# $646,106,625.00   $906,493,799.15   44,291
# -0.011%
# 34
#
#
# Injective Token
# (INJ)
#
#
# $7.65
#
#
# 0.004670 ETH
#
# 1.95%
#
# $19,818,299.00
# $641,895,783.00   $765,000,000.00   17,057
# 0.082%
# 35
#
#
# SAND
# (SAND)
#
#
# $0.2968
#
#
# 0.000181 ETH
#
# 0.22%
#
# $33,844,039.00
# $613,068,016.00   $890,400,000.00   210,513
# 0.018%
# 36
#
#
# HEX
# (HEX)
#
#
# $0.0034
#
#
# 0.000002 ETH
#
# 5.65%
#
# $389,095.00
# $592,597,419.00   $1,973,721,419.03   330,157
# 0.000%
# 37
#
#
# Fantom Token
# (FTM)
#
#
# $0.1981
#
#
# 0.000121 ETH
#
# -1.01%
#
# $34,091,237.00
# $556,731,999.00   $423,617,443.53   106,531
# -0.006%
# 38
#
#
# Decentraland
# (MANA)
#
#
# $0.2993
#
#
# 0.000183 ETH
#
# 0.77%
#
# $28,339,925.00
# $552,139,186.00   $656,570,210.40   307,016
# 0.011%
# 39
#
#
# Wrapped Decentraland MANA
# (wMANA)
#
#
# $0.2993
#
#
# 0.000183 ETH
#
# 0.77%
#
# $28,339,925.00
# $552,139,186.00   $9,349,660.50   1
# 0.000%
# 40
#
#
# Rollbit Coin
# (RLB)
#
#
# $0.1522
#
#
# 0.000093 ETH
#
# 2.41%
#
# $6,051,570.00
# $501,848,563.00   $490,605,357.79   10,702
# 0.505%
# 41
#
#
# Pax Dollar
# (USDP)
#
#
# $0.9988
#
#
# 0.000610 ETH
#
# --
#
# $2,301,923.00
# $485,583,273.00   $1,082,640,225.40   109,893
# 0.003%
# 42
#
#
# Paxos Gold
# (PAXG)
#
#
# $1,839.17
#
#
# 1.122850 ETH
#
# 0.33%
#
# $24,983,916.00
# $457,548,888.00   $363,914,728.73   31,090
# -0.045%
# 43
#
#
# Compound Ether
# (cETH)
#
#
# $32.94
#
#
# 0.020111 ETH
#
# -0.42%
#
# $50.00
# $453,121,636.00   $1,733,516,481.78   72,175
# 0.001%
# 44
#
#
# Tether Gold
# (XAUt)
#
#
# $1,823.18
#
#
# 1.113088 ETH
#
# -0.17%
#
# $5,373,059.00
# $449,360,395.00   $412,565,579.02   1,285
# 0.233%
# 45
#
#
# Frax Ether
# (frxETH)
#
#
# $1,636.97
#
#
# 0.999403 ETH
#
# -0.45%
#
# $820,816.00
# $439,031,648.00   $118,172,864.30   1,322
# 0.227%
# 46
#
#
# KuCoin Token
# (KCS)
#
#
# $4.5061
#
#
# 0.002751 ETH
#
# -1.09%
#
# $710,887.00
# $435,888,559.00   $749,948,780.58   6,894
# 0.058%
# 47
#
#
# chiliZ
# (CHZ)
#
#
# $0.0606
#
#
# 0.000037 ETH
#
# 0.16%
#
# $34,588,378.00
# $423,216,109.00   $539,031,111.06   120,248
# 0.019%
# 48
#
#
# ApeCoin
# (APE)
#
#
# $1.13
#
#
# 0.000690 ETH
#
# -1.26%
#
# $29,949,613.00
# $417,056,974.00   $1,130,000,000.00   138,656
# 0.022%
# 49
#
#
# Frax Share
# (FXS)
#
#
# $5.60
#
#
# 0.003419 ETH
#
# 1.38%
#
# $22,432,450.00
# $416,569,171.00   $559,417,320.00   14,941
# 0.040%
# 50
#
#
# Rocket Pool
# (RPL)
#
#
# $20.74
#
#
# 0.012662 ETH
#
# -2.85%
#
# $2,986,444.00
# $410,970,573.00   $377,535,425.74   9,796
# -0.020%
# 51
#
#
# HuobiToken
# (HT)
#
#
# $2.36
#
#
# 0.001441 ETH
#
# -0.53%
#
# $3,406,311.00
# $377,061,857.00   $1,180,000,000.00   52,100
# -0.002%
# 52
#
#
# BitTorrent
# (BTT)
#
#
# $0.00
#
#
# 0.000000 ETH
#
# -0.14%
#
# $6,750,196.00
# $366,462,494.00   $5,638,937.02   19,800
# 0.015%
# 53
#
#
# dYdX
# (DYDX)
#
#
# $1.99
#
#
# 0.001215 ETH
#
# 0.54%
#
# $30,221,395.00
# $351,670,681.00   $1,990,000,000.00   48,939
# 0.116%
# 54
#
#
# UnlimitedIP Token
# (UIP)
#
#
# $0.2038
#
#
# 0.000124 ETH
#
# 25.76%
#
# $149,600.00
# $342,362,271.00   $611,366,464.90   6,334
# -0.142%
# 55
#
#
# APENFT
# (NFT)
#
#
# $0.00
#
#
# 0.000000 ETH
#
# 0.90%
#
# $12,455,513.00
# $324,466,138.00   $5,786.20   1,249
# 0.160%
# 56
#
#
# Coinbase Wrapped Staked ETH
# (cbETH)
#
#
# $1,719.49
#
#
# 1.049783 ETH
#
# -0.64%
#
# $1,537,833.00
# $323,506,997.00   $1,477,219,017.47   41,168
# 0.138%
# 57
#
#
# Staked Frax Ether
# (sfrxETH)
#
#
# $1,736.91
#
#
# 1.060418 ETH
#
# -0.41%
#
# $56,753.00
# $322,292,446.00   $59,146,996.23   2,758
# -0.109%
# 58
#
#
# Nexo
# (NEXO)
#
#
# $0.5697
#
#
# 0.000348 ETH
#
# 2.45%
#
# $2,189,438.00
# $318,680,280.00   $569,726,000.00   78,631
# 0.010%
# 59
#
#
# Wootrade Network
# (WOO)
#
#
# $0.1831
#
#
# 0.000112 ETH
#
# 3.43%
#
# $8,994,433.00
# $318,064,277.00   $549,366,000.00   16,197
# 0.019%
# 60
#
#
# NXM
# (NXM)
#
#
# $47.05
#
#
# 0.028725 ETH
#
# -0.40%
#
# $13,521.00
# $317,996,975.00   $324,221,550.00   4,050
# 0.000%
# 61
#
#
# Compound
# (COMP)
#
#
# $43.65
#
#
# 0.026649 ETH
#
# -0.32%
#
# $41,487,390.00
# $299,984,538.00   $436,500,000.00   215,555
# 0.009%
# 62
#
#
# Pepe
# (PEPE)
#
#
# $0.00
#
#
# 0.000000 ETH
#
# 0.41%
#
# $37,338,538.00
# $281,778,068.00   $302,563,146.73   138,311
# 0.029%
# 63
#
#
# Zilliqa
# (ZIL)
#
#
# $0.0167
#
#
# 0.000010 ETH
#
# -0.20%
#
# $10,585,171.00
# $264,720,450.00   $2,784,782.21   23,503
# 0.000%
# 64
#
#
# 1INCH Token
# (1INCH)
#
#
# $0.2537
#
#
# 0.000155 ETH
#
# -1.00%
#
# $11,238,764.00
# $262,673,574.00   $380,554,500.00   95,149
# 0.027%
# 65
#
#
# BAT
# (BAT)
#
#
# $0.1748
#
#
# 0.000107 ETH
#
# 0.71%
#
# $22,469,522.00
# $260,354,781.00   $262,227,000.00   463,909
# 0.006%
# 66
#
#
# PancakeSwap Token
# (Cake)
#
#
# $1.19
#
#
# 0.000727 ETH
#
# 0.48%
#
# $18,615,558.00
# $258,837,517.00   $2,254,349.09   7,752
# 0.064%
# 67
#
#
# Gnosis
# (GNO)
#
#
# $97.71
#
#
# 0.059654 ETH
#
# -0.84%
#
# $1,351,252.00
# $253,181,690.00   $977,100,000.00   19,028
# -0.032%
# 68
#
#
# MCO
# (MCO)
#
#
# $15.9471
#
#
# 0.009736 ETH
#
# 31.13%
#
# $1,414,724.00
# $251,866,368.00   $503,733,050.94   26,371
# 0.000%
# 69
#
#
# SafePalToken
# (SFP)
#
#
# $0.5878
#
#
# 0.000359 ETH
#
# 0.95%
#
# $6,773,210.00
# $247,975,110.00   $117,565,200.00   91
# 0.000%
# 70
#
#
# Huobi BTC
# (HBTC)
#
#
# $27,563.00
#
#
# 16.827764 ETH
#
# 0.37%
#
# $8,732.00
# $247,053,720.00   $1,099,322,692.00   2,585
# 0.000%
# 71
#
#
# WQtum
# (WQTUM)
#
#
# $2.251
#
#
# 0.001374 ETH
#
# 2.53%
#
# $19,234,039.00
# $235,806,699.00   $242,709,572.09   43
# 0.000%
# 72
#
#
# Convex Token
# (CVX)
#
#
# $2.8583
#
#
# 0.001745 ETH
#
# -2.27%
#
# $5,174,621.00
# $231,396,403.00   $239,849,113.81   21,492
# -0.009%
# 73
#
#
# Illuvium
# (ILV)
#
#
# $39.17
#
#
# 0.023914 ETH
#
# -0.55%
#
# $1,560,180.00
# $231,043,926.00   $274,190,000.00   40,304
# 0.007%
# 74
#
#
# Fetch
# (FET)
#
#
# $0.2182
#
#
# 0.000133 ETH
#
# -1.08%
#
# $14,405,350.00
# $227,602,953.00   $251,569,081.90   48,661
# 0.037%
# 75
#
#
# MX Token
# (MX)
#
#
# $2.23
#
#
# 0.001361 ETH
#
# -0.59%
#
# $1,278,680.00
# $225,070,143.00   $1,003,500,000.00   2,226
# 0.090%
# 76
#
#
# Compound USDT
# (cUSDT)
#
#
# $0.0191
#
#
# 0.000012 ETH
#
# --
#
# $124.00
# $223,314,026.00   $722,149,978.88   5,994
# -0.033%
# 77
#
#
# EnjinCoin
# (ENJ)
#
#
# $0.2233
#
#
# 0.000136 ETH
#
# -0.41%
#
# $10,694,722.00
# $223,114,426.00   $223,335,000.00   171,785
# 0.002%
# 78
#
#
# Celo native asset (Wormhole)
# (CELO)
#
#
# $0.4329
#
#
# 0.000264 ETH
#
# 0.23%
#
# $6,864,346.00
# $222,983,613.00   $107,260.63   31
# 0.000%
# 79
#
#
# Wrapped Celo
# (wCELO)
#
#
# $0.4329
#
#
# 0.000264 ETH
#
# 0.23%
#
# $6,864,346.00
# $222,983,613.00   $630,637.84   250
# 0.000%
# 80
#
#
# Gemini dollar
# (GUSD)
#
#
# $0.9999
#
#
# 0.000610 ETH
#
# -0.04%
#
# $365,795.00
# $222,326,577.00   $251,210,076.99   12,678
# -0.008%
# 81
#
#
# SingularityNET Token
# (AGIX)
#
#
# $0.1792
#
#
# 0.000109 ETH
#
# -1.23%
#
# $15,965,709.00
# $221,304,587.00   $179,243,000.00   69,778
# 0.021%
# 82
#
#
# Mask Network
# (MASK)
#
#
# $2.68
#
#
# 0.001636 ETH
#
# 1.80%
#
# $16,084,353.00
# $220,346,015.00   $268,000,000.00   12,733
# -0.008%
# 83
#
#
# LoopringCoin V2
# (LRC)
#
#
# $0.1757
#
#
# 0.000107 ETH
#
# -0.63%
#
# $8,448,831.00
# $218,792,845.00   $241,353,842.70   167,733
# 0.005%
# 84
#
#
# Euro Tether
# (EURT)
#
#
# $1.052
#
#
# 0.000642 ETH
#
# 0.03%
#
# $1,137,896.00
# $216,620,423.00   $420,800,052.60   976
# 0.102%
# 85
#
#
# DeFiChain Token
# (DFI)
#
#
# $0.2865
#
#
# 0.000175 ETH
#
# -0.24%
#
# $5,432,006.00
# $215,172,453.00   $2,386,728.26   2,871
# -0.035%
# 86
#
#
# Compound USD Coin
# (cUSDC)
#
#
# $0.0231
#
#
# 0.000014 ETH
#
# -0.03%
#
# $24.00
# $212,236,278.00   $2,772,589,820.35   216,336
# -0.001%
# 87
#
#
# Worldcoin
# (WLD)
#
#
# $1.57
#
#
# 0.000959 ETH
#
# 3.45%
#
# $33,001,120.00
# $207,704,894.00   $15,700,000,000.00   7,257
# 0.138%
# 88
#
#
# Ethereum Name Service
# (ENS)
#
#
# $7.82
#
#
# 0.004774 ETH
#
# 0.59%
#
# $11,890,049.00
# $201,772,810.00   $782,000,000.00   65,459
# 0.086%
# 89
#
#
# Aragon Network Token
# (ANT)
#
#
# $4.92
#
#
# 0.003004 ETH
#
# 1.03%
#
# $9,457,878.00
# $196,689,794.00   $211,706,665.20   15,107
# 0.007%
# 90
#
#
# Olympus
# (OHM)
#
#
# $11.28
#
#
# 0.006887 ETH
#
# 0.08%
#
# $30,701.00
# $193,767,346.00   $129,076,306.80   7,032
# -0.014%
# 91
#
#
# FLOKI
# (FLOKI)
#
#
# $0.00
#
#
# 0.000000 ETH
#
# 5.21%
#
# $21,167,114.00
# $185,498,339.00   $185,800,000.00   73,006
# 0.022%
# 92
#
#
# Golem Network Token
# (GLM)
#
#
# $0.184
#
#
# 0.000112 ETH
#
# 2.08%
#
# $9,250,543.00
# $184,023,035.00   $103,024,792.89   18,314
# 0.060%
# 93
#
#
# GreenMetaverseToken
# (GMT)
#
#
# $0.152
#
#
# 0.000093 ETH
#
# 0.22%
#
# $11,377,203.00
# $181,614,277.00   $8,830,928.64   11,401
# -0.026%
# 94
#
#
# HoloToken
# (HOT)
#
#
# $0.001
#
#
# 0.000001 ETH
#
# 0.16%
#
# $5,543,659.00
# $180,637,239.00   $180,344,115.65   125,304
# 0.001%
# 95
#
#
# yearn.finance
# (YFI)
#
#
# $5,338.43
#
#
# 3.259219 ETH
#
# 2.12%
#
# $16,702,680.00
# $176,952,534.00   $195,738,874.38   51,974
# 0.015%
# 96
#
#
# Livepeer Token
# (LPT)
#
#
# $5.84
#
#
# 0.003565 ETH
#
# -2.29%
#
# $10,032,052.00
# $171,385,461.00   $145,399,764.80   2,214,783
# -0.001%
# 97
#
#
# SwissBorg
# (CHSB)
#
#
# $0.1767
#
#
# 0.000108 ETH
#
# 3.58%
#
# $760,177.00
# $169,312,466.00   $176,729,000.00   18,478
# 0.000%
# 98
#
#
# Blur
# (BLUR)
#
#
# $0.1741
#
#
# 0.000106 ETH
#
# 1.00%
#
# $22,394,808.00
# $169,052,418.00   $522,402,000.00   41,492
# 0.000%
# 99
#
#
# Compound Dai
# (cDAI)
#
#
# $0.0224
#
#
# 0.000014 ETH
#
# 0.02%
#
# $154.00
# $166,725,648.00   $2,997,776,968.07   17,997
# 0.006%
# 100
#
#
# IoTeX Network
# (IOTX)
#
#
# $0.0175
#
#
# 0.000011 ETH
#
# 3.74%
#
# $9,244,693.00
# $165,080,797.00   $174,802,216.08   21,435
# 0.005%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Show:
#
# 10
# 25
# 50
# 100
#
# Records
#
#
# FirstPreviousPage 1 of 13NextLastLast
#
#
#
#
#
#
#
#
# This page tracks key metrics of ERC-20 tokens on Ethereum. Kindly take note that only tokens with a Blue Checkmark are listed. Learn more about our Blue Checkmark feature in our Knowledge Base.
#
#
#
#
#
#
#
#
#
#
#
# ×
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Before You Copy
#
#
#
#
#
#
#
# Don't show this for 30 days
#
#
#
#
# Understand, Copy Address
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Back to Top
#
#
#
#
#
#
#
#
# Powered by Ethereum
#
# Etherscan is a Block Explorer and Analytics Platform for Ethereum, a decentralized smart contracts platform.
#
#
#
#
#
#
# Company
#
# About Us
# Brand Assets
# Contact Us
#
#
# Careers We're Hiring!
#
#
# Terms of Service
# Bug Bounty
#
#
#
# Community
#
# API Documentation
# Knowledge Base
# Network Status
# Newsletters
# Disqus Comments
#
#
#
# Products & Services
#
# Advertise
# Explorer-as-a-Service (EaaS)
# API Plans
# Priority Support
# Blockscan
# Blockscan Chat
#
#
#
#
#
#
# Etherscan © 2023 (B1)
#
#
#
# Donations: 0x71c765...d8976f
#
#
#
#
#
#
#
#
#
#
#  This website uses cookies to improve your experience. By continuing to use this website, you agree to its Terms and Privacy Policy.
#
# Got it!

# %%
import re

# %%
print(re.sub(r'(\n\s*)+\n', '\n', soup.get_text().replace('\t', '')))
# Out:
# Token Tracker | Etherscan
# ETH Price: $1,637.95 (-0.52%) Gas: 6 Gwei
# /
#  Light
#  Dim
#  Dark
#  Site Settings
# Ethereum Mainnet
# Ethereum Mainnet CN
# Beaconscan ETH2
# Goerli Testnet
# Sepolia Testnet
# Holesky Testnet
#  Sign In
# Home
# Blockchain
# Transactions
# Pending Transactions
# Contract Internal Transactions
# Beacon Deposits
# Beacon Withdrawals
# View Blocks
# Forked Blocks (Reorgs)
# Uncles
# Top Accounts
# Verified Contracts
# Tokens
# Top Tokens (ERC-20)
# Token Transfers (ERC-20)
# NFTs
# Top NFTs
# Top Mints
# Latest Trades
# Latest Transfers
# Latest Mints
# Resources
# Charts And Stats
# Top Statistics
# Directory
# Newsletter
# Knowledge Base
# Developers
# API Plans
# API Documentation
# Code Reader Beta
# Verify Contract
# Similar Contract Search
# Smart Contract Search
# Contract Diff Checker
# Vyper Online Compiler
# Bytecode to Opcode
# Broadcast Transaction
# More
# Tools & Services
# Discover more of Etherscan's tools and services in one place.
# Sponsored
# Tools
# Unit Converter
# CSV Export
# Account Balance Checker
# Explore
# Gas Tracker
# DEX Tracker
# Node Tracker
# Label Cloud
# Domain Name Lookup
# Services
# Token Approvals Beta
# Verified Signature
# Input Data Messages (IDM) Beta
# Advanced Filter Beta
# Blockscan Chat  Beta
# Explorers
# Ethereum Mainnet
# Ethereum Mainnet CN
# Beaconscan ETH2
# Goerli Testnet
# Sepolia Testnet
# Holesky Testnet
# Appearance & Settings
#  Light
#  Dim
#  Dark
#  Site Settings
# |
#  Sign In
# Token Tracker
# (ERC-20)
# A total of 1,239 Token Contracts found
# Find
# #
# Token
# Price
# Change (%)
# Volume (24H)
# Circulating Market Cap
# On-Chain Market Cap
# Holders
# 1
# Tether USD
# (USDT)
# $1.00
# 0.000611 ETH
# 0.01%
# $16,279,573,188.00
# $83,369,918,594.00   $39,823,119,845.00   4,580,187
# -0.094%
# 2
# BNB
# (BNB)
# $212.7507
# 0.129889 ETH
# 0.08%
# $332,364,359.00
# $32,730,872,926.00   $3,527,304,388.67   285,796
# 0.009%
# 3
# USDC
# (USDC)
# $1.00
# 0.000611 ETH
# 0.07%
# $3,879,695,290.00
# $25,255,348,953.00   $46,602,430,840.00   1,790,688
# -0.046%
# 4
# stETH
# (stETH)
# $1,640.60
# 1.001619 ETH
# -0.42%
# $5,560,941.00
# $14,459,518,712.00   $3,041,030,925.40   270,064
# 0.064%
# 5
# TRON
# (TRX)
# $0.0888
# 0.000054 ETH
# --
# $224,534,429.00
# $7,904,153,443.00   $231.06   2,208
# 0.317%
# 6
# Wrapped TON Coin
# (TONCOIN)
# $2.09
# 0.001276 ETH
# 4.32%
# $16,895,926.00
# $7,200,646,823.00   $15,354,617.63   7,677
# 0.000%
# 7
# Theta Token
# (THETA)
# $5.2667
# 0.003215 ETH
# -9.81%
# $271,444,395.00
# $5,266,695,404.00   $5,266,695,404.45   28,402
# 0.000%
# 8
# Matic Token
# (MATIC)
# $0.5634
# 0.000344 ETH
# -3.46%
# $301,112,205.00
# $5,239,075,310.00   $5,633,533,626.77   629,170
# 0.004%
# 9
# Wrapped BTC
# (WBTC)
# $27,671.00
# 16.893700 ETH
# 0.46%
# $83,442,076.00
# $4,503,832,873.00   $7,244,655,194.00   77,850
# 0.041%
# 10
# ChainLink Token
# (LINK)
# $7.71
# 0.004707 ETH
# 1.78%
# $273,603,042.00
# $4,286,153,187.00   $7,710,000,000.00   679,837
# 0.020%
# 11
# SHIBA INU
# (SHIB)
# $0.00
# 0.000000 ETH
# 0.03%
# $63,605,814.00
# $4,256,971,078.00   $7,229,940,957.62   1,344,151
# 0.010%
# 12
# Dai Stablecoin
# (DAI)
# $1.001
# 0.000611 ETH
# 0.05%
# $100,304,495.00
# $3,825,552,887.00   $9,809,451,981.33   496,640
# -0.010%
# 13
# Bitfinex LEO Token
# (LEO)
# $3.79
# 0.002314 ETH
# 1.53%
# $355,074.00
# $3,519,235,387.00   $2,501,400,000.00   2,715
# 0.000%
# 14
# TrueUSD
# (TUSD)
# $0.9996
# 0.000610 ETH
# 0.04%
# $172,835,976.00
# $3,433,625,634.00   $1,137,165,473.05   51,652
# 0.014%
# 15
# Uniswap
# (UNI)
# $4.31
# 0.002631 ETH
# -0.31%
# $62,360,278.00
# $3,247,043,893.00   $4,310,000,000.00   366,305
# 0.035%
# 16
# OKB
# (OKB)
# $42.93
# 0.026210 ETH
# -0.46%
# $1,631,572.00
# $2,576,159,427.00   $12,879,000,000.00   50,685
# 0.006%
# 17
# BUSD
# (BUSD)
# $1.001
# 0.000611 ETH
# 0.02%
# $2,052,507,915.00
# $2,238,214,231.00   $17,592,669,900.81   167,547
# -0.019%
# 18
# Lido DAO Token
# (LDO)
# $1.57
# 0.000959 ETH
# -2.59%
# $25,611,792.00
# $1,396,878,569.00   $1,570,000,000.00   40,562
# 0.030%
# 19
# Cronos Coin
# (CRO)
# $0.0504
# 0.000031 ETH
# 0.27%
# $4,402,001.00
# $1,327,024,224.00   $5,037,300,000.00   300,896
# 0.008%
# 20
# Maker
# (MKR)
# $1,468.27
# 0.896408 ETH
# 2.94%
# $79,250,227.00
# $1,319,095,018.00   $1,435,426,268.37   94,345
# 0.001%
# 21
# Mantle
# (MNT)
# $0.4065
# 0.000248 ETH
# -0.33%
# $24,281,345.00
# $1,315,152,327.00   $2,527,940,820.40   7,363
# 0.380%
# 22
# Quant
# (QNT)
# $87.19
# 0.053231 ETH
# -1.17%
# $19,674,500.00
# $1,266,832,393.00   $3,964,267,730.00   145,511
# -0.003%
# 23
# VeChain
# (VEN)
# $0.0167
# 0.000010 ETH
# 0.09%
# $27,265,862.00
# $1,213,753,211.00   $16,692,034.32   46,198
# 0.000%
# 24
# Arbitrum
# (ARB)
# $0.8836
# 0.000539 ETH
# -0.10%
# $110,457,446.00
# $1,124,825,365.00   $4,572.76   12,798
# 0.016%
# 25
# NEAR
# (NEAR)
# $1.10
# 0.000672 ETH
# 1.43%
# $46,323,511.00
# $1,078,334,429.00   $432,191.10   1,281
# 0.000%
# 26
# Staked Aave
# (stkAAVE)
# $68.86
# 0.042040 ETH
# 5.70%
# $115,049,487.00
# $1,006,086,011.00   $194,851,076.20   20,528
# 0.029%
# 27
# Rocket Pool ETH
# (rETH)
# $1,781.23
# 1.087477 ETH
# -0.42%
# $2,520,965.00
# $944,379,964.00   $81,135,026.50   18,879
# 0.042%
# 28
# Graph Token
# (GRT)
# $0.0859
# 0.000052 ETH
# -1.34%
# $24,550,461.00
# $793,426,182.00   $884,378,571.35   142,390
# 0.021%
# 29
# Decentralized USD
# (USDD)
# $1.00
# 0.000611 ETH
# 0.12%
# $33,255,779.00
# $729,779,001.00   $3,099,947.30   1,054
# 0.000%
# 30
# Frax
# (FRAX)
# $0.9971
# 0.000609 ETH
# 0.01%
# $5,233,494.00
# $669,456,406.00   $2,645,513,263.59   8,206
# 0.012%
# 31
# Immutable X
# (IMX)
# $0.5679
# 0.000347 ETH
# -0.38%
# $518,767,987.00
# $662,994,933.00   $1,135,846,000.00   57,083
# 0.054%
# 32
# Synthetix Network Token
# (SNX)
# $2.02
# 0.001233 ETH
# -0.16%
# $28,060,560.00
# $659,971,475.00   $489,888,531.50   94,738
# 0.006%
# 33
# Render Token
# (RNDR)
# $1.73
# 0.001056 ETH
# 2.93%
# $28,556,770.00
# $646,106,625.00   $906,493,799.15   44,291
# -0.011%
# 34
# Injective Token
# (INJ)
# $7.65
# 0.004670 ETH
# 1.95%
# $19,818,299.00
# $641,895,783.00   $765,000,000.00   17,057
# 0.082%
# 35
# SAND
# (SAND)
# $0.2968
# 0.000181 ETH
# 0.22%
# $33,844,039.00
# $613,068,016.00   $890,400,000.00   210,513
# 0.018%
# 36
# HEX
# (HEX)
# $0.0034
# 0.000002 ETH
# 5.65%
# $389,095.00
# $592,597,419.00   $1,973,721,419.03   330,157
# 0.000%
# 37
# Fantom Token
# (FTM)
# $0.1981
# 0.000121 ETH
# -1.01%
# $34,091,237.00
# $556,731,999.00   $423,617,443.53   106,531
# -0.006%
# 38
# Decentraland
# (MANA)
# $0.2993
# 0.000183 ETH
# 0.77%
# $28,339,925.00
# $552,139,186.00   $656,570,210.40   307,016
# 0.011%
# 39
# Wrapped Decentraland MANA
# (wMANA)
# $0.2993
# 0.000183 ETH
# 0.77%
# $28,339,925.00
# $552,139,186.00   $9,349,660.50   1
# 0.000%
# 40
# Rollbit Coin
# (RLB)
# $0.1522
# 0.000093 ETH
# 2.41%
# $6,051,570.00
# $501,848,563.00   $490,605,357.79   10,702
# 0.505%
# 41
# Pax Dollar
# (USDP)
# $0.9988
# 0.000610 ETH
# --
# $2,301,923.00
# $485,583,273.00   $1,082,640,225.40   109,893
# 0.003%
# 42
# Paxos Gold
# (PAXG)
# $1,839.17
# 1.122850 ETH
# 0.33%
# $24,983,916.00
# $457,548,888.00   $363,914,728.73   31,090
# -0.045%
# 43
# Compound Ether
# (cETH)
# $32.94
# 0.020111 ETH
# -0.42%
# $50.00
# $453,121,636.00   $1,733,516,481.78   72,175
# 0.001%
# 44
# Tether Gold
# (XAUt)
# $1,823.18
# 1.113088 ETH
# -0.17%
# $5,373,059.00
# $449,360,395.00   $412,565,579.02   1,285
# 0.233%
# 45
# Frax Ether
# (frxETH)
# $1,636.97
# 0.999403 ETH
# -0.45%
# $820,816.00
# $439,031,648.00   $118,172,864.30   1,322
# 0.227%
# 46
# KuCoin Token
# (KCS)
# $4.5061
# 0.002751 ETH
# -1.09%
# $710,887.00
# $435,888,559.00   $749,948,780.58   6,894
# 0.058%
# 47
# chiliZ
# (CHZ)
# $0.0606
# 0.000037 ETH
# 0.16%
# $34,588,378.00
# $423,216,109.00   $539,031,111.06   120,248
# 0.019%
# 48
# ApeCoin
# (APE)
# $1.13
# 0.000690 ETH
# -1.26%
# $29,949,613.00
# $417,056,974.00   $1,130,000,000.00   138,656
# 0.022%
# 49
# Frax Share
# (FXS)
# $5.60
# 0.003419 ETH
# 1.38%
# $22,432,450.00
# $416,569,171.00   $559,417,320.00   14,941
# 0.040%
# 50
# Rocket Pool
# (RPL)
# $20.74
# 0.012662 ETH
# -2.85%
# $2,986,444.00
# $410,970,573.00   $377,535,425.74   9,796
# -0.020%
# 51
# HuobiToken
# (HT)
# $2.36
# 0.001441 ETH
# -0.53%
# $3,406,311.00
# $377,061,857.00   $1,180,000,000.00   52,100
# -0.002%
# 52
# BitTorrent
# (BTT)
# $0.00
# 0.000000 ETH
# -0.14%
# $6,750,196.00
# $366,462,494.00   $5,638,937.02   19,800
# 0.015%
# 53
# dYdX
# (DYDX)
# $1.99
# 0.001215 ETH
# 0.54%
# $30,221,395.00
# $351,670,681.00   $1,990,000,000.00   48,939
# 0.116%
# 54
# UnlimitedIP Token
# (UIP)
# $0.2038
# 0.000124 ETH
# 25.76%
# $149,600.00
# $342,362,271.00   $611,366,464.90   6,334
# -0.142%
# 55
# APENFT
# (NFT)
# $0.00
# 0.000000 ETH
# 0.90%
# $12,455,513.00
# $324,466,138.00   $5,786.20   1,249
# 0.160%
# 56
# Coinbase Wrapped Staked ETH
# (cbETH)
# $1,719.49
# 1.049783 ETH
# -0.64%
# $1,537,833.00
# $323,506,997.00   $1,477,219,017.47   41,168
# 0.138%
# 57
# Staked Frax Ether
# (sfrxETH)
# $1,736.91
# 1.060418 ETH
# -0.41%
# $56,753.00
# $322,292,446.00   $59,146,996.23   2,758
# -0.109%
# 58
# Nexo
# (NEXO)
# $0.5697
# 0.000348 ETH
# 2.45%
# $2,189,438.00
# $318,680,280.00   $569,726,000.00   78,631
# 0.010%
# 59
# Wootrade Network
# (WOO)
# $0.1831
# 0.000112 ETH
# 3.43%
# $8,994,433.00
# $318,064,277.00   $549,366,000.00   16,197
# 0.019%
# 60
# NXM
# (NXM)
# $47.05
# 0.028725 ETH
# -0.40%
# $13,521.00
# $317,996,975.00   $324,221,550.00   4,050
# 0.000%
# 61
# Compound
# (COMP)
# $43.65
# 0.026649 ETH
# -0.32%
# $41,487,390.00
# $299,984,538.00   $436,500,000.00   215,555
# 0.009%
# 62
# Pepe
# (PEPE)
# $0.00
# 0.000000 ETH
# 0.41%
# $37,338,538.00
# $281,778,068.00   $302,563,146.73   138,311
# 0.029%
# 63
# Zilliqa
# (ZIL)
# $0.0167
# 0.000010 ETH
# -0.20%
# $10,585,171.00
# $264,720,450.00   $2,784,782.21   23,503
# 0.000%
# 64
# 1INCH Token
# (1INCH)
# $0.2537
# 0.000155 ETH
# -1.00%
# $11,238,764.00
# $262,673,574.00   $380,554,500.00   95,149
# 0.027%
# 65
# BAT
# (BAT)
# $0.1748
# 0.000107 ETH
# 0.71%
# $22,469,522.00
# $260,354,781.00   $262,227,000.00   463,909
# 0.006%
# 66
# PancakeSwap Token
# (Cake)
# $1.19
# 0.000727 ETH
# 0.48%
# $18,615,558.00
# $258,837,517.00   $2,254,349.09   7,752
# 0.064%
# 67
# Gnosis
# (GNO)
# $97.71
# 0.059654 ETH
# -0.84%
# $1,351,252.00
# $253,181,690.00   $977,100,000.00   19,028
# -0.032%
# 68
# MCO
# (MCO)
# $15.9471
# 0.009736 ETH
# 31.13%
# $1,414,724.00
# $251,866,368.00   $503,733,050.94   26,371
# 0.000%
# 69
# SafePalToken
# (SFP)
# $0.5878
# 0.000359 ETH
# 0.95%
# $6,773,210.00
# $247,975,110.00   $117,565,200.00   91
# 0.000%
# 70
# Huobi BTC
# (HBTC)
# $27,563.00
# 16.827764 ETH
# 0.37%
# $8,732.00
# $247,053,720.00   $1,099,322,692.00   2,585
# 0.000%
# 71
# WQtum
# (WQTUM)
# $2.251
# 0.001374 ETH
# 2.53%
# $19,234,039.00
# $235,806,699.00   $242,709,572.09   43
# 0.000%
# 72
# Convex Token
# (CVX)
# $2.8583
# 0.001745 ETH
# -2.27%
# $5,174,621.00
# $231,396,403.00   $239,849,113.81   21,492
# -0.009%
# 73
# Illuvium
# (ILV)
# $39.17
# 0.023914 ETH
# -0.55%
# $1,560,180.00
# $231,043,926.00   $274,190,000.00   40,304
# 0.007%
# 74
# Fetch
# (FET)
# $0.2182
# 0.000133 ETH
# -1.08%
# $14,405,350.00
# $227,602,953.00   $251,569,081.90   48,661
# 0.037%
# 75
# MX Token
# (MX)
# $2.23
# 0.001361 ETH
# -0.59%
# $1,278,680.00
# $225,070,143.00   $1,003,500,000.00   2,226
# 0.090%
# 76
# Compound USDT
# (cUSDT)
# $0.0191
# 0.000012 ETH
# --
# $124.00
# $223,314,026.00   $722,149,978.88   5,994
# -0.033%
# 77
# EnjinCoin
# (ENJ)
# $0.2233
# 0.000136 ETH
# -0.41%
# $10,694,722.00
# $223,114,426.00   $223,335,000.00   171,785
# 0.002%
# 78
# Celo native asset (Wormhole)
# (CELO)
# $0.4329
# 0.000264 ETH
# 0.23%
# $6,864,346.00
# $222,983,613.00   $107,260.63   31
# 0.000%
# 79
# Wrapped Celo
# (wCELO)
# $0.4329
# 0.000264 ETH
# 0.23%
# $6,864,346.00
# $222,983,613.00   $630,637.84   250
# 0.000%
# 80
# Gemini dollar
# (GUSD)
# $0.9999
# 0.000610 ETH
# -0.04%
# $365,795.00
# $222,326,577.00   $251,210,076.99   12,678
# -0.008%
# 81
# SingularityNET Token
# (AGIX)
# $0.1792
# 0.000109 ETH
# -1.23%
# $15,965,709.00
# $221,304,587.00   $179,243,000.00   69,778
# 0.021%
# 82
# Mask Network
# (MASK)
# $2.68
# 0.001636 ETH
# 1.80%
# $16,084,353.00
# $220,346,015.00   $268,000,000.00   12,733
# -0.008%
# 83
# LoopringCoin V2
# (LRC)
# $0.1757
# 0.000107 ETH
# -0.63%
# $8,448,831.00
# $218,792,845.00   $241,353,842.70   167,733
# 0.005%
# 84
# Euro Tether
# (EURT)
# $1.052
# 0.000642 ETH
# 0.03%
# $1,137,896.00
# $216,620,423.00   $420,800,052.60   976
# 0.102%
# 85
# DeFiChain Token
# (DFI)
# $0.2865
# 0.000175 ETH
# -0.24%
# $5,432,006.00
# $215,172,453.00   $2,386,728.26   2,871
# -0.035%
# 86
# Compound USD Coin
# (cUSDC)
# $0.0231
# 0.000014 ETH
# -0.03%
# $24.00
# $212,236,278.00   $2,772,589,820.35   216,336
# -0.001%
# 87
# Worldcoin
# (WLD)
# $1.57
# 0.000959 ETH
# 3.45%
# $33,001,120.00
# $207,704,894.00   $15,700,000,000.00   7,257
# 0.138%
# 88
# Ethereum Name Service
# (ENS)
# $7.82
# 0.004774 ETH
# 0.59%
# $11,890,049.00
# $201,772,810.00   $782,000,000.00   65,459
# 0.086%
# 89
# Aragon Network Token
# (ANT)
# $4.92
# 0.003004 ETH
# 1.03%
# $9,457,878.00
# $196,689,794.00   $211,706,665.20   15,107
# 0.007%
# 90
# Olympus
# (OHM)
# $11.28
# 0.006887 ETH
# 0.08%
# $30,701.00
# $193,767,346.00   $129,076,306.80   7,032
# -0.014%
# 91
# FLOKI
# (FLOKI)
# $0.00
# 0.000000 ETH
# 5.21%
# $21,167,114.00
# $185,498,339.00   $185,800,000.00   73,006
# 0.022%
# 92
# Golem Network Token
# (GLM)
# $0.184
# 0.000112 ETH
# 2.08%
# $9,250,543.00
# $184,023,035.00   $103,024,792.89   18,314
# 0.060%
# 93
# GreenMetaverseToken
# (GMT)
# $0.152
# 0.000093 ETH
# 0.22%
# $11,377,203.00
# $181,614,277.00   $8,830,928.64   11,401
# -0.026%
# 94
# HoloToken
# (HOT)
# $0.001
# 0.000001 ETH
# 0.16%
# $5,543,659.00
# $180,637,239.00   $180,344,115.65   125,304
# 0.001%
# 95
# yearn.finance
# (YFI)
# $5,338.43
# 3.259219 ETH
# 2.12%
# $16,702,680.00
# $176,952,534.00   $195,738,874.38   51,974
# 0.015%
# 96
# Livepeer Token
# (LPT)
# $5.84
# 0.003565 ETH
# -2.29%
# $10,032,052.00
# $171,385,461.00   $145,399,764.80   2,214,783
# -0.001%
# 97
# SwissBorg
# (CHSB)
# $0.1767
# 0.000108 ETH
# 3.58%
# $760,177.00
# $169,312,466.00   $176,729,000.00   18,478
# 0.000%
# 98
# Blur
# (BLUR)
# $0.1741
# 0.000106 ETH
# 1.00%
# $22,394,808.00
# $169,052,418.00   $522,402,000.00   41,492
# 0.000%
# 99
# Compound Dai
# (cDAI)
# $0.0224
# 0.000014 ETH
# 0.02%
# $154.00
# $166,725,648.00   $2,997,776,968.07   17,997
# 0.006%
# 100
# IoTeX Network
# (IOTX)
# $0.0175
# 0.000011 ETH
# 3.74%
# $9,244,693.00
# $165,080,797.00   $174,802,216.08   21,435
# 0.005%
# Show:
# 10
# 25
# 50
# 100
# Records
# FirstPreviousPage 1 of 13NextLastLast
# This page tracks key metrics of ERC-20 tokens on Ethereum. Kindly take note that only tokens with a Blue Checkmark are listed. Learn more about our Blue Checkmark feature in our Knowledge Base.
# ×
# Before You Copy
# Don't show this for 30 days
# Understand, Copy Address
# Back to Top
# Powered by Ethereum
# Etherscan is a Block Explorer and Analytics Platform for Ethereum, a decentralized smart contracts platform.
# Company
# About Us
# Brand Assets
# Contact Us
# Careers We're Hiring!
# Terms of Service
# Bug Bounty
# Community
# API Documentation
# Knowledge Base
# Network Status
# Newsletters
# Disqus Comments
# Products & Services
# Advertise
# Explorer-as-a-Service (EaaS)
# API Plans
# Priority Support
# Blockscan
# Blockscan Chat
# Etherscan © 2023 (B1)
# Donations: 0x71c765...d8976f
#  This website uses cookies to improve your experience. By continuing to use this website, you agree to its Terms and Privacy Policy.
# Got it!

# %% [markdown]
# **2. Get the content of the element**
# * `soup.title` - get the title of the page
# * `soup.title.string` - get the string in the title element
# * `soup.h1` - get the H1 element in the web page
# * `soup.h1.attrs` - get all attributes in the H1 element
# * `soup.h1['class']` - get the class attribute in the H1 element

# %%
# Get the title of the page
soup.title.text.strip()
# Out:
# 'Token Tracker | Etherscan'

# %%
# Other HTML elements also work too
soup.h1.text.strip()
# Out:
# 'Token Tracker\n(ERC-20)'

# %%
# Get the class attribute of an element
soup.h1['class']
# Out:
# ['h5', 'mb-0']

# %% [markdown]
# **3. Look for the element in the web page**
# * `soup.find('HTML_tag')` - get the element from an HTML tag
# * `soup.find_all('HTML_tag')` - get the list of elelemts that has the specified HTML tag
# * `soup.select('CSS_selector')` - get the list of elements with the specified [CSS selector](https://www.w3schools.com/cssref/css_selectors.asp)

# %%
# We can also get the page title using soup.find() function
soup.find('title').text.strip()
# Out:
# 'Token Tracker | Etherscan'

# %%
# Get all the elements with image tag
for i in soup.find_all('img', {"class": "rounded-circle"}):
    print(i['src'])
# Out:
# /token/images/tethernew_32.png
# /token/images/bnb_28_2.png
# /token/images/centre-usdc_28.png
# /token/images/lido-steth_32.png
# /token/images/trontrx_32.png
# /token/images/theopennetwork_32.png
# /token/images/theta_28.png
# /token/images/polygonmatic_new_32.png
# /token/images/wbtc_28.png?v=1
# /token/images/chainlinktoken_32.png?v=6
# /token/images/shibatoken_32.png
# /token/images/MCDDai_32.png
# /token/images/leo_28_2.png
# /token/images/trueusd_32.png?v=2
# /token/images/uniswap_32.png
# /token/images/okex_28.png
# /images/main/empty-token.png
# /token/images/lido-dao_32.png
# /token/images/cro_32.png
# /token/images/mkr-etherscan-35.png
# /token/images/mantle_32.png
# /token/images/quantnetwork_28_2.png?v=6
# /token/images/vechain_28.png
# /token/images/arbitrumone2_32.png
# /token/images/near_32.png?v=3
# /token/images/stakedaave_32.png
# /token/images/rocketpooleth_32.png?v=2
# /token/images/TheGraph_32.png
# /token/images/usdd-tron_32.png
# /token/images/fraxfinanceeth2_32.png
# /token/images/immutable_32.png
# /token/images/SynthetixSNX_32.png
# /token/images/Render2_32.png
# /token/images/injective_32.png?v=3
# /token/images/sand_32.png
# /token/images/hex_32.png
# /token/images/fantomtoken_32.png
# /token/images/decentraland_32.png?v=1
# /token/images/decentraland_32.png?v=1
# /token/images/rollbitcoin_32.png
# /token/images/paxos-usdp_32.png
# /token/images/paxosgold_32.png
# /token/images/compound-eth_28.png
# /token/images/tethergoldnew_32.png
# /token/images/fraxethcanonical2_32.png
# /token/images/kucointoken_32.png
# /token/images/chiliz_28.png
# /token/images/apecoin_32.png
# /token/images/fraxfxs_new_32.png
# /token/images/Rocketpool_32.png
# /token/images/huobi_28.png
# /token/images/bittorrent_32.png
# /token/images/dydx2_32.png
# /token/images/unlimitedip_28.png
# /token/images/apenfttron_32.png
# /token/images/cbeth_32.png
# /token/images/sfrxeth2_32.png
# /token/images/nexo_32_2.png
# /token/images/wootrade_32.png?=v2
# /token/images/nxm_32.png?v=2
# /token/images/comp_32.png
# /token/images/pepe_32.png?=v1
# /token/images/zilliqa_28_2.png
# /token/images/1inch_32.png
# /token/images/bat.png
# /token/images/pancake_32.png?v=2
# /token/images/gnosans_32.png?v=2
# /token/images/cryptocom_28.png
# /token/images/safepal_32.png
# /token/images/huobibtc_32.png
# /token/images/qtum_28.png
# /token/images/convex_32.png
# /token/images/illuvium_32.png
# /token/images/fetch_32.png?v=2
# /token/images/mexc_32.png
# /token/images/compoundcUSDT_32.png
# /token/images/enjin_28_2.png
# /token/images/celowormhole_32.png
# /token/images/wrappedcelo_32.png
# /token/images/gemini_28.png
# /token/images/singularitynet_28.png
# /token/images/mask_32.png
# /token/images/lrc_32.png
# /token/images/tethernew_32.png
# /token/images/defichain_32.png
# /token/images/compound-usdc_28.png
# /token/images/worldcoin_32.png
# /token/images/ens2_32.png?v=2
# /token/images/aragonnetworktoken_32.png?=v2
# /token/images/olympusdao2_32.png
# /token/images/floki_32.png
# /token/images/golem-glm_32.png?v=2
# /token/images/stepngmt_32.png
# /token/images/holo_28.png
# /token/images/yfi_32_2.png
# /token/images/livepeer_28.png?v=8
# /token/images/swissborg_28_3.png
# /token/images/blurio_32.png
# /token/images/compounddai_32.png
# /token/images/iotex_28.png

# %%
# Get all the token names on the web page
for i in soup.select('.hash-tag'):
    print(i.text)
# Out:
# Tether USD
# BNB
# USDC
# stETH
# TRON
# Wrapped TON Coin
# Theta Token
# Matic Token
# Wrapped BTC
# ChainLink Token
# SHIBA INU
# Dai Stablecoin
# Bitfinex LEO Token
# TrueUSD
# Uniswap
# OKB
# BUSD
# Lido DAO Token
# Cronos Coin
# Maker
# Mantle
# Quant
# VeChain
# Arbitrum
# NEAR
# Staked Aave
# Rocket Pool ETH
# Graph Token
# Decentralized USD
# Frax
# Immutable X
# Synthetix Network Token
# Render Token
# Injective Token
# SAND
# HEX
# Fantom Token
# Decentraland
# Wrapped Decentraland MANA
# Rollbit Coin
# Pax Dollar
# Paxos Gold
# Compound Ether
# Tether Gold
# Frax Ether
# KuCoin Token
# chiliZ
# ApeCoin
# Frax Share
# Rocket Pool
# HuobiToken
# BitTorrent
# dYdX
# UnlimitedIP Token
# APENFT
# Coinbase Wrapped Staked ETH
# Staked Frax Ether
# Nexo
# Wootrade Network
# NXM
# Compound
# Pepe
# Zilliqa
# 1INCH Token
# BAT
# PancakeSwap Token
# Gnosis
# MCO
# SafePalToken
# Huobi BTC
# WQtum
# Convex Token
# Illuvium
# Fetch
# MX Token
# Compound USDT
# EnjinCoin
# Celo native asset (Wormhole)
# Wrapped Celo
# Gemini dollar
# SingularityNET Token
# Mask Network
# LoopringCoin V2
# Euro Tether
# DeFiChain Token
# Compound USD Coin
# Worldcoin
# Ethereum Name Service
# Aragon Network Token
# Olympus
# FLOKI
# Golem Network Token
# GreenMetaverseToken
# HoloToken
# yearn.finance
# Livepeer Token
# SwissBorg
# Blur
# Compound Dai
# IoTeX Network

# %% [markdown]
# ## Step 3: Extract the data from the table
#
# Now, we will extract the cryptocurrencies market price from the table.

# %%
# Get the table element in the web page
table = soup.table

# %%
# Get the table headers
col_names = list()
for i in table.tr.find_all('th'):
    print(i.text.strip())
    col_names.append(i.text.strip())
# Out:
# #
# Token
# Price
# Change (%)
# Volume (24H)
# Circulating Market Cap
# On-Chain Market Cap
# Holders

# %% [markdown]
# For loop over each row in the table and extract the data for each column in the row.

# %%
data = list()
# For loop over each row in the table
for row in table.tbody.find_all('tr'):
    # Get all the columns in the row
    cols = row.find_all('td')

    d = list()
    # For loop over each column and extract the string
    for idx, col in enumerate(cols):
        print(idx, ':', col.text.strip())
        d.append(col.text.strip())

    print('--------------------------')
    data.append(d)
# Out:
# 0 : 1
# 1 : Tether USD
# (USDT)
# 2 : $1.00
#
#
# 0.000610 ETH
# 3 : --
# 4 : $16,289,778,116.00
# 5 : $83,369,918,594.00
# 6 : $39,823,119,845.00
# 7 : 4,580,187
# -0.094%
# --------------------------
# 0 : 2
# 1 : BNB
# (BNB)
# 2 : $212.7004
#
#
# 0.129764 ETH
# 3 : 0.05%
# 4 : $331,713,816.00
# 5 : $32,723,133,157.00
# 6 : $3,526,470,297.89
# 7 : 285,796
# 0.009%
# --------------------------
# 0 : 3
# 1 : USDC
# (USDC)
# 2 : $1.00
#
#
# 0.000610 ETH
# 3 : 0.02%
# 4 : $4,270,444,800.00
# 5 : $25,255,348,953.00
# 6 : $46,602,430,840.00
# 7 : 1,790,688
# -0.046%
# --------------------------
# 0 : 4
# 1 : stETH
# (stETH)
# 2 : $1,639.23
#
#
# 1.000062 ETH
# 3 : -0.47%
# 4 : $5,520,449.00
# 5 : $14,459,518,712.00
# 6 : $3,038,491,481.07
# 7 : 270,064
# 0.064%
# --------------------------
# 0 : 5
# 1 : TRON
# (TRX)
# 2 : $0.0888
#
#
# 0.000054 ETH
# 3 : -0.01%
# 4 : $219,852,244.00
# 5 : $7,904,153,443.00
# 6 : $230.91
# 7 : 2,208
# 0.317%
# --------------------------
# 0 : 6
# 1 : Wrapped TON Coin
# (TONCOIN)
# 2 : $2.08
#
#
# 0.001269 ETH
# 3 : 3.61%
# 4 : $16,339,632.00
# 5 : $7,200,646,823.00
# 6 : $15,281,150.56
# 7 : 7,677
# 0.000%
# --------------------------
# 0 : 7
# 1 : Theta Token
# (THETA)
# 2 : $5.2667
#
#
# 0.003213 ETH
# 3 : -9.81%
# 4 : $271,444,395.00
# 5 : $5,266,695,404.00
# 6 : $5,266,695,404.45
# 7 : 28,402
# 0.000%
# --------------------------
# 0 : 8
# 1 : Matic Token
# (MATIC)
# 2 : $0.5625
#
#
# 0.000343 ETH
# 3 : -3.59%
# 4 : $300,491,385.00
# 5 : $5,231,238,991.00
# 6 : $5,625,107,298.97
# 7 : 629,170
# 0.004%
# --------------------------
# 0 : 9
# 1 : Wrapped BTC
# (WBTC)
# 2 : $27,665.00
#
#
# 16.877866 ETH
# 3 : 0.51%
# 4 : $75,328,838.00
# 5 : $4,503,832,873.00
# 6 : $7,243,084,310.00
# 7 : 77,850
# 0.041%
# --------------------------
# 0 : 10
# 1 : ChainLink Token
# (LINK)
# 2 : $7.71
#
#
# 0.004704 ETH
# 3 : 1.98%
# 4 : $273,217,471.00
# 5 : $4,286,153,187.00
# 6 : $7,710,000,000.00
# 7 : 679,837
# 0.020%
# --------------------------
# 0 : 11
# 1 : SHIBA INU
# (SHIB)
# 2 : $0.00
#
#
# 0.000000 ETH
# 3 : -0.05%
# 4 : $59,070,755.00
# 5 : $4,256,971,078.00
# 6 : $7,219,941,039.28
# 7 : 1,344,151
# 0.010%
# --------------------------
# 0 : 12
# 1 : Dai Stablecoin
# (DAI)
# 2 : $1.00
#
#
# 0.000610 ETH
# 3 : 0.07%
# 4 : $106,088,788.00
# 5 : $3,825,552,887.00
# 6 : $9,799,652,329.00
# 7 : 496,640
# -0.010%
# --------------------------
# 0 : 13
# 1 : Bitfinex LEO Token
# (LEO)
# 2 : $3.79
#
#
# 0.002312 ETH
# 3 : 1.54%
# 4 : $354,345.00
# 5 : $3,519,235,387.00
# 6 : $2,501,400,000.00
# 7 : 2,715
# 0.000%
# --------------------------
# 0 : 14
# 1 : TrueUSD
# (TUSD)
# 2 : $0.9994
#
#
# 0.000610 ETH
# 3 : 0.01%
# 4 : $172,724,980.00
# 5 : $3,433,625,634.00
# 6 : $1,136,844,675.29
# 7 : 51,652
# 0.014%
# --------------------------
# 0 : 15
# 1 : Uniswap
# (UNI)
# 2 : $4.31
#
#
# 0.002629 ETH
# 3 : -0.38%
# 4 : $61,892,209.00
# 5 : $3,247,043,893.00
# 6 : $4,310,000,000.00
# 7 : 366,305
# 0.035%
# --------------------------
# 0 : 16
# 1 : OKB
# (OKB)
# 2 : $42.95
#
#
# 0.026203 ETH
# 3 : -0.50%
# 4 : $1,631,624.00
# 5 : $2,576,159,427.00
# 6 : $12,885,000,000.00
# 7 : 50,685
# 0.006%
# --------------------------
# 0 : 17
# 1 : BUSD
# (BUSD)
# 2 : $0.9998
#
#
# 0.000610 ETH
# 3 : -0.02%
# 4 : $1,906,311,983.00
# 5 : $2,238,214,231.00
# 6 : $17,571,351,310.81
# 7 : 167,547
# -0.019%
# --------------------------
# 0 : 18
# 1 : Lido DAO Token
# (LDO)
# 2 : $1.57
#
#
# 0.000958 ETH
# 3 : -2.57%
# 4 : $25,671,758.00
# 5 : $1,396,878,569.00
# 6 : $1,570,000,000.00
# 7 : 40,562
# 0.030%
# --------------------------
# 0 : 19
# 1 : Cronos Coin
# (CRO)
# 2 : $0.0504
#
#
# 0.000031 ETH
# 3 : 0.40%
# 4 : $4,412,513.00
# 5 : $1,327,024,224.00
# 6 : $5,043,500,000.00
# 7 : 300,896
# 0.008%
# --------------------------
# 0 : 20
# 1 : Maker
# (MKR)
# 2 : $1,465.93
#
#
# 0.894335 ETH
# 3 : 3.01%
# 4 : $78,640,017.00
# 5 : $1,319,095,018.00
# 6 : $1,433,138,611.83
# 7 : 94,345
# 0.001%
# --------------------------
# 0 : 21
# 1 : Mantle
# (MNT)
# 2 : $0.4065
#
#
# 0.000248 ETH
# 3 : -0.18%
# 4 : $24,305,400.00
# 5 : $1,315,152,327.00
# 6 : $2,528,295,321.45
# 7 : 7,363
# 0.380%
# --------------------------
# 0 : 22
# 1 : Quant
# (QNT)
# 2 : $87.16
#
#
# 0.053175 ETH
# 3 : -1.20%
# 4 : $19,622,518.00
# 5 : $1,266,832,393.00
# 6 : $3,962,903,720.00
# 7 : 145,511
# -0.003%
# --------------------------
# 0 : 23
# 1 : VeChain
# (VEN)
# 2 : $0.0167
#
#
# 0.000010 ETH
# 3 : 0.05%
# 4 : $27,293,109.00
# 5 : $1,213,176,954.00
# 6 : $16,684,109.41
# 7 : 46,198
# 0.000%
# --------------------------
# 0 : 24
# 1 : Arbitrum
# (ARB)
# 2 : $0.8827
#
#
# 0.000539 ETH
# 3 : -0.15%
# 4 : $109,298,325.00
# 5 : $1,124,825,365.00
# 6 : $4,568.09
# 7 : 12,798
# 0.016%
# --------------------------
# 0 : 25
# 1 : NEAR
# (NEAR)
# 2 : $1.10
#
#
# 0.000671 ETH
# 3 : 1.37%
# 4 : $45,766,329.00
# 5 : $1,078,334,429.00
# 6 : $432,191.10
# 7 : 1,281
# 0.000%
# --------------------------
# 0 : 26
# 1 : Staked Aave
# (stkAAVE)
# 2 : $68.92
#
#
# 0.042047 ETH
# 3 : 5.89%
# 4 : $114,744,642.00
# 5 : $1,006,086,011.00
# 6 : $195,020,856.40
# 7 : 20,528
# 0.029%
# --------------------------
# 0 : 27
# 1 : Rocket Pool ETH
# (rETH)
# 2 : $1,780.55
#
#
# 1.086278 ETH
# 3 : -0.49%
# 4 : $2,424,790.00
# 5 : $944,379,964.00
# 6 : $81,104,052.50
# 7 : 18,879
# 0.042%
# --------------------------
# 0 : 28
# 1 : Graph Token
# (GRT)
# 2 : $0.0858
#
#
# 0.000052 ETH
# 3 : -1.35%
# 4 : $24,432,026.00
# 5 : $793,426,182.00
# 6 : $883,750,556.62
# 7 : 142,390
# 0.021%
# --------------------------
# 0 : 29
# 1 : Decentralized USD
# (USDD)
# 2 : $0.9996
#
#
# 0.000610 ETH
# 3 : 0.11%
# 4 : $10,741,930.00
# 5 : $729,779,001.00
# 6 : $3,098,812.70
# 7 : 1,054
# 0.000%
# --------------------------
# 0 : 30
# 1 : Frax
# (FRAX)
# 2 : $0.9967
#
#
# 0.000608 ETH
# 3 : -0.03%
# 4 : $5,199,779.00
# 5 : $669,456,406.00
# 6 : $2,644,587,282.08
# 7 : 8,206
# 0.012%
# --------------------------
# 0 : 31
# 1 : Immutable X
# (IMX)
# 2 : $0.568
#
#
# 0.000347 ETH
# 3 : -0.03%
# 4 : $519,305,947.00
# 5 : $662,994,933.00
# 6 : $1,135,962,000.00
# 7 : 57,083
# 0.054%
# --------------------------
# 0 : 32
# 1 : Synthetix Network Token
# (SNX)
# 2 : $2.03
#
#
# 0.001238 ETH
# 3 : 0.31%
# 4 : $27,564,273.00
# 5 : $659,971,475.00
# 6 : $492,313,722.25
# 7 : 94,738
# 0.006%
# --------------------------
# 0 : 33
# 1 : Render Token
# (RNDR)
# 2 : $1.74
#
#
# 0.001062 ETH
# 3 : 3.27%
# 4 : $28,421,355.00
# 5 : $646,106,625.00
# 6 : $911,733,647.70
# 7 : 44,291
# -0.011%
# --------------------------
# 0 : 34
# 1 : Injective Token
# (INJ)
# 2 : $7.65
#
#
# 0.004667 ETH
# 3 : 2.01%
# 4 : $19,857,141.00
# 5 : $641,895,783.00
# 6 : $765,000,000.00
# 7 : 17,057
# 0.082%
# --------------------------
# 0 : 35
# 1 : SAND
# (SAND)
# 2 : $0.2965
#
#
# 0.000181 ETH
# 3 : 0.08%
# 4 : $30,868,217.00
# 5 : $613,068,016.00
# 6 : $889,464,000.00
# 7 : 210,513
# 0.018%
# --------------------------
# 0 : 36
# 1 : HEX
# (HEX)
# 2 : $0.0034
#
#
# 0.000002 ETH
# 3 : 5.84%
# 4 : $397,668.00
# 5 : $592,593,228.00
# 6 : $1,973,707,459.73
# 7 : 330,157
# 0.000%
# --------------------------
# 0 : 37
# 1 : Fantom Token
# (FTM)
# 2 : $0.1981
#
#
# 0.000121 ETH
# 3 : -0.88%
# 4 : $34,036,857.00
# 5 : $556,731,999.00
# 6 : $423,602,476.46
# 7 : 106,531
# -0.006%
# --------------------------
# 0 : 38
# 1 : Decentraland
# (MANA)
# 2 : $0.2993
#
#
# 0.000183 ETH
# 3 : 0.75%
# 4 : $26,618,906.00
# 5 : $552,139,186.00
# 6 : $656,600,924.26
# 7 : 307,016
# 0.011%
# --------------------------
# 0 : 39
# 1 : Wrapped Decentraland MANA
# (wMANA)
# 2 : $0.2993
#
#
# 0.000183 ETH
# 3 : 0.75%
# 4 : $26,618,906.00
# 5 : $552,139,186.00
# 6 : $9,350,097.87
# 7 : 1
# 0.000%
# --------------------------
# 0 : 40
# 1 : Rollbit Coin
# (RLB)
# 2 : $0.1519
#
#
# 0.000093 ETH
# 3 : 2.05%
# 4 : $6,041,938.00
# 5 : $500,668,524.00
# 6 : $489,451,755.53
# 7 : 10,702
# 0.505%
# --------------------------
# 0 : 41
# 1 : Pax Dollar
# (USDP)
# 2 : $0.9993
#
#
# 0.000610 ETH
# 3 : 0.07%
# 4 : $2,304,447.00
# 5 : $485,583,273.00
# 6 : $1,083,196,280.98
# 7 : 109,893
# 0.003%
# --------------------------
# 0 : 42
# 1 : Paxos Gold
# (PAXG)
# 2 : $1,840.00
#
#
# 1.122547 ETH
# 3 : 0.34%
# 4 : $23,665,135.00
# 5 : $457,548,888.00
# 6 : $364,078,960.00
# 7 : 31,090
# -0.045%
# --------------------------
# 0 : 43
# 1 : Compound Ether
# (cETH)
# 2 : $32.94
#
#
# 0.020096 ETH
# 3 : -0.42%
# 4 : $50.00
# 5 : $453,121,636.00
# 6 : $1,733,516,481.78
# 7 : 72,175
# 0.001%
# --------------------------
# 0 : 44
# 1 : Tether Gold
# (XAUt)
# 2 : $1,822.69
#
#
# 1.111987 ETH
# 3 : -0.17%
# 4 : $5,377,729.00
# 5 : $449,360,395.00
# 6 : $412,454,697.41
# 7 : 1,285
# 0.233%
# --------------------------
# 0 : 45
# 1 : Frax Ether
# (frxETH)
# 2 : $1,636.05
#
#
# 0.998122 ETH
# 3 : -0.49%
# 4 : $818,816.00
# 5 : $439,031,648.00
# 6 : $118,106,449.50
# 7 : 1,322
# 0.227%
# --------------------------
# 0 : 46
# 1 : KuCoin Token
# (KCS)
# 2 : $4.5035
#
#
# 0.002747 ETH
# 3 : -1.17%
# 4 : $707,988.00
# 5 : $435,633,130.00
# 6 : $749,509,313.83
# 7 : 6,894
# 0.058%
# --------------------------
# 0 : 47
# 1 : chiliZ
# (CHZ)
# 2 : $0.0607
#
#
# 0.000037 ETH
# 3 : 0.32%
# 4 : $34,281,025.00
# 5 : $423,216,109.00
# 6 : $539,324,444.39
# 7 : 120,248
# 0.019%
# --------------------------
# 0 : 48
# 1 : ApeCoin
# (APE)
# 2 : $1.13
#
#
# 0.000689 ETH
# 3 : -0.97%
# 4 : $29,338,909.00
# 5 : $417,056,974.00
# 6 : $1,130,000,000.00
# 7 : 138,656
# 0.022%
# --------------------------
# 0 : 49
# 1 : Frax Share
# (FXS)
# 2 : $5.61
#
#
# 0.003423 ETH
# 3 : 1.43%
# 4 : $22,483,014.00
# 5 : $416,569,171.00
# 6 : $560,416,279.50
# 7 : 14,941
# 0.040%
# --------------------------
# 0 : 50
# 1 : Rocket Pool
# (RPL)
# 2 : $20.75
#
#
# 0.012659 ETH
# 3 : -2.91%
# 4 : $2,964,700.00
# 5 : $410,970,573.00
# 6 : $377,717,458.25
# 7 : 9,796
# -0.020%
# --------------------------
# 0 : 51
# 1 : HuobiToken
# (HT)
# 2 : $2.37
#
#
# 0.001446 ETH
# 3 : -0.53%
# 4 : $3,409,756.00
# 5 : $377,061,857.00
# 6 : $1,185,000,000.00
# 7 : 52,100
# -0.002%
# --------------------------
# 0 : 52
# 1 : BitTorrent
# (BTT)
# 2 : $0.00
#
#
# 0.000000 ETH
# 3 : -0.30%
# 4 : $6,753,967.00
# 5 : $366,664,609.00
# 6 : $5,642,047.05
# 7 : 19,800
# 0.015%
# --------------------------
# 0 : 53
# 1 : dYdX
# (DYDX)
# 2 : $1.99
#
#
# 0.001214 ETH
# 3 : 0.52%
# 4 : $29,888,068.00
# 5 : $351,670,681.00
# 6 : $1,990,000,000.00
# 7 : 48,939
# 0.116%
# --------------------------
# 0 : 54
# 1 : UnlimitedIP Token
# (UIP)
# 2 : $0.2038
#
#
# 0.000124 ETH
# 3 : 12.69%
# 4 : $149,600.00
# 5 : $342,364,164.00
# 6 : $611,369,846.17
# 7 : 6,334
# -0.142%
# --------------------------
# 0 : 55
# 1 : APENFT
# (NFT)
# 2 : $0.00
#
#
# 0.000000 ETH
# 3 : 0.78%
# 4 : $12,515,695.00
# 5 : $324,389,450.00
# 6 : $5,784.84
# 7 : 1,249
# 0.160%
# --------------------------
# 0 : 56
# 1 : Coinbase Wrapped Staked ETH
# (cbETH)
# 2 : $1,718.10
#
#
# 1.048179 ETH
# 3 : -0.61%
# 4 : $1,558,880.00
# 5 : $323,506,997.00
# 6 : $1,476,024,864.30
# 7 : 41,168
# 0.138%
# --------------------------
# 0 : 57
# 1 : Staked Frax Ether
# (sfrxETH)
# 2 : $1,735.46
#
#
# 1.058770 ETH
# 3 : -0.44%
# 4 : $56,705.00
# 5 : $322,292,446.00
# 6 : $59,097,619.38
# 7 : 2,758
# -0.109%
# --------------------------
# 0 : 58
# 1 : Nexo
# (NEXO)
# 2 : $0.5695
#
#
# 0.000347 ETH
# 3 : 2.42%
# 4 : $2,197,834.00
# 5 : $318,680,280.00
# 6 : $569,513,000.00
# 7 : 78,631
# 0.010%
# --------------------------
# 0 : 59
# 1 : Wootrade Network
# (WOO)
# 2 : $0.1824
#
#
# 0.000111 ETH
# 3 : 3.30%
# 4 : $8,677,531.00
# 5 : $318,064,277.00
# 6 : $547,140,000.00
# 7 : 16,197
# 0.019%
# --------------------------
# 0 : 60
# 1 : NXM
# (NXM)
# 2 : $47.05
#
#
# 0.028704 ETH
# 3 : -0.40%
# 4 : $13,521.00
# 5 : $317,996,975.00
# 6 : $324,221,550.00
# 7 : 4,050
# 0.000%
# --------------------------
# 0 : 61
# 1 : Compound
# (COMP)
# 2 : $43.64
#
#
# 0.026624 ETH
# 3 : -0.49%
# 4 : $41,456,863.00
# 5 : $299,984,538.00
# 6 : $436,400,000.00
# 7 : 215,555
# 0.009%
# --------------------------
# 0 : 62
# 1 : Pepe
# (PEPE)
# 2 : $0.00
#
#
# 0.000000 ETH
# 3 : 0.21%
# 4 : $36,985,360.00
# 5 : $281,930,740.00
# 6 : $302,727,080.63
# 7 : 138,311
# 0.029%
# --------------------------
# 0 : 63
# 1 : Zilliqa
# (ZIL)
# 2 : $0.0167
#
#
# 0.000010 ETH
# 3 : -0.28%
# 4 : $10,595,156.00
# 5 : $264,685,571.00
# 6 : $2,784,415.29
# 7 : 23,503
# 0.000%
# --------------------------
# 0 : 64
# 1 : 1INCH Token
# (1INCH)
# 2 : $0.2537
#
#
# 0.000155 ETH
# 3 : -0.87%
# 4 : $11,004,885.00
# 5 : $262,673,574.00
# 6 : $380,562,000.00
# 7 : 95,149
# 0.027%
# --------------------------
# 0 : 65
# 1 : BAT
# (BAT)
# 2 : $0.1748
#
#
# 0.000107 ETH
# 3 : 0.72%
# 4 : $22,408,815.00
# 5 : $260,354,781.00
# 6 : $262,189,500.00
# 7 : 463,909
# 0.006%
# --------------------------
# 0 : 66
# 1 : PancakeSwap Token
# (Cake)
# 2 : $1.19
#
#
# 0.000726 ETH
# 3 : 0.49%
# 4 : $18,831,493.00
# 5 : $258,837,517.00
# 6 : $2,254,349.09
# 7 : 7,752
# 0.064%
# --------------------------
# 0 : 67
# 1 : Gnosis
# (GNO)
# 2 : $97.75
#
#
# 0.059635 ETH
# 3 : -0.84%
# 4 : $1,343,322.00
# 5 : $253,181,690.00
# 6 : $977,500,000.00
# 7 : 19,028
# -0.032%
# --------------------------
# 0 : 68
# 1 : MCO
# (MCO)
# 2 : $15.9471
#
#
# 0.009729 ETH
# 3 : 31.13%
# 4 : $1,414,724.00
# 5 : $251,866,368.00
# 6 : $503,733,050.94
# 7 : 26,371
# 0.000%
# --------------------------
# 0 : 69
# 1 : SafePalToken
# (SFP)
# 2 : $0.5893
#
#
# 0.000360 ETH
# 3 : 1.19%
# 4 : $6,769,605.00
# 5 : $247,975,110.00
# 6 : $117,860,800.00
# 7 : 91
# 0.000%
# --------------------------
# 0 : 70
# 1 : Huobi BTC
# (HBTC)
# 2 : $27,579.00
#
#
# 16.825399 ETH
# 3 : 0.11%
# 4 : $6,100.00
# 5 : $247,053,720.00
# 6 : $1,099,960,836.00
# 7 : 2,585
# 0.000%
# --------------------------
# 0 : 71
# 1 : WQtum
# (WQTUM)
# 2 : $2.2505
#
#
# 0.001373 ETH
# 3 : 2.52%
# 4 : $19,207,614.00
# 5 : $235,748,979.00
# 6 : $242,650,163.14
# 7 : 43
# 0.000%
# --------------------------
# 0 : 72
# 1 : Convex Token
# (CVX)
# 2 : $2.8607
#
#
# 0.001745 ETH
# 3 : -2.21%
# 4 : $5,168,430.00
# 5 : $231,597,468.00
# 6 : $240,057,523.62
# 7 : 21,492
# -0.009%
# --------------------------
# 0 : 73
# 1 : Illuvium
# (ILV)
# 2 : $39.18
#
#
# 0.023903 ETH
# 3 : -0.65%
# 4 : $1,571,743.00
# 5 : $231,043,926.00
# 6 : $274,260,000.00
# 7 : 40,304
# 0.007%
# --------------------------
# 0 : 74
# 1 : Fetch
# (FET)
# 2 : $0.2181
#
#
# 0.000133 ETH
# 3 : -1.11%
# 4 : $14,287,880.00
# 5 : $227,602,953.00
# 6 : $251,418,039.21
# 7 : 48,661
# 0.037%
# --------------------------
# 0 : 75
# 1 : MX Token
# (MX)
# 2 : $2.23
#
#
# 0.001360 ETH
# 3 : -0.62%
# 4 : $1,283,838.00
# 5 : $225,070,143.00
# 6 : $1,003,500,000.00
# 7 : 2,226
# 0.090%
# --------------------------
# 0 : 76
# 1 : Compound USDT
# (cUSDT)
# 2 : $0.0191
#
#
# 0.000012 ETH
# 3 : --
# 4 : $124.00
# 5 : $223,314,026.00
# 6 : $722,149,978.88
# 7 : 5,994
# -0.033%
# --------------------------
# 0 : 77
# 1 : EnjinCoin
# (ENJ)
# 2 : $0.2232
#
#
# 0.000136 ETH
# 3 : 0.04%
# 4 : $10,652,997.00
# 5 : $223,114,426.00
# 6 : $223,242,000.00
# 7 : 171,785
# 0.002%
# --------------------------
# 0 : 78
# 1 : Celo native asset (Wormhole)
# (CELO)
# 2 : $0.4329
#
#
# 0.000264 ETH
# 3 : 0.28%
# 4 : $6,845,213.00
# 5 : $222,962,114.00
# 6 : $107,250.28
# 7 : 31
# 0.000%
# --------------------------
# 0 : 79
# 1 : Wrapped Celo
# (wCELO)
# 2 : $0.4329
#
#
# 0.000264 ETH
# 3 : 0.28%
# 4 : $6,845,213.00
# 5 : $222,962,114.00
# 6 : $630,577.03
# 7 : 250
# 0.000%
# --------------------------
# 0 : 80
# 1 : Gemini dollar
# (GUSD)
# 2 : $0.9991
#
#
# 0.000610 ETH
# 3 : -0.16%
# 4 : $365,523.00
# 5 : $222,326,577.00
# 6 : $251,023,404.01
# 7 : 12,678
# -0.008%
# --------------------------
# 0 : 81
# 1 : SingularityNET Token
# (AGIX)
# 2 : $0.1791
#
#
# 0.000109 ETH
# 3 : -1.14%
# 4 : $16,490,415.00
# 5 : $221,304,587.00
# 6 : $179,100,000.00
# 7 : 69,778
# 0.021%
# --------------------------
# 0 : 82
# 1 : Mask Network
# (MASK)
# 2 : $2.68
#
#
# 0.001635 ETH
# 3 : 1.76%
# 4 : $15,946,091.00
# 5 : $220,346,015.00
# 6 : $268,000,000.00
# 7 : 12,733
# -0.008%
# --------------------------
# 0 : 83
# 1 : LoopringCoin V2
# (LRC)
# 2 : $0.1757
#
#
# 0.000107 ETH
# 3 : -0.65%
# 4 : $8,560,236.00
# 5 : $218,792,845.00
# 6 : $241,326,365.23
# 7 : 167,733
# 0.005%
# --------------------------
# 0 : 84
# 1 : Euro Tether
# (EURT)
# 2 : $1.054
#
#
# 0.000643 ETH
# 3 : 0.22%
# 4 : $1,138,898.00
# 5 : $216,620,423.00
# 6 : $421,600,052.70
# 7 : 976
# 0.102%
# --------------------------
# 0 : 85
# 1 : DeFiChain Token
# (DFI)
# 2 : $0.2866
#
#
# 0.000175 ETH
# 3 : -0.13%
# 4 : $5,396,385.00
# 5 : $215,172,453.00
# 6 : $2,387,519.61
# 7 : 2,871
# -0.035%
# --------------------------
# 0 : 86
# 1 : Compound USD Coin
# (cUSDC)
# 2 : $0.0231
#
#
# 0.000014 ETH
# 3 : -0.03%
# 4 : $24.00
# 5 : $212,236,278.00
# 6 : $2,772,589,820.35
# 7 : 216,336
# -0.001%
# --------------------------
# 0 : 87
# 1 : Worldcoin
# (WLD)
# 2 : $1.56
#
#
# 0.000952 ETH
# 3 : 3.31%
# 4 : $34,412,139.00
# 5 : $207,704,894.00
# 6 : $15,600,000,000.00
# 7 : 7,257
# 0.138%
# --------------------------
# 0 : 88
# 1 : Ethereum Name Service
# (ENS)
# 2 : $7.82
#
#
# 0.004771 ETH
# 3 : 0.57%
# 4 : $11,946,987.00
# 5 : $201,772,810.00
# 6 : $782,000,000.00
# 7 : 65,459
# 0.086%
# --------------------------
# 0 : 89
# 1 : Aragon Network Token
# (ANT)
# 2 : $4.92
#
#
# 0.003002 ETH
# 3 : 1.06%
# 4 : $9,428,655.00
# 5 : $196,689,794.00
# 6 : $211,706,665.20
# 7 : 15,107
# 0.007%
# --------------------------
# 0 : 90
# 1 : Olympus
# (OHM)
# 2 : $11.28
#
#
# 0.006882 ETH
# 3 : 0.08%
# 4 : $30,706.00
# 5 : $193,767,346.00
# 6 : $129,076,306.80
# 7 : 7,032
# -0.014%
# --------------------------
# 0 : 91
# 1 : FLOKI
# (FLOKI)
# 2 : $0.00
#
#
# 0.000000 ETH
# 3 : 5.40%
# 4 : $20,830,514.00
# 5 : $185,498,339.00
# 6 : $185,800,000.00
# 7 : 73,006
# 0.022%
# --------------------------
# 0 : 92
# 1 : Golem Network Token
# (GLM)
# 2 : $0.1838
#
#
# 0.000112 ETH
# 3 : 1.90%
# 4 : $9,250,499.00
# 5 : $183,841,408.00
# 6 : $102,923,109.18
# 7 : 18,314
# 0.060%
# --------------------------
# 0 : 93
# 1 : GreenMetaverseToken
# (GMT)
# 2 : $0.1519
#
#
# 0.000093 ETH
# 3 : 0.21%
# 4 : $11,195,643.00
# 5 : $181,614,277.00
# 6 : $8,821,460.00
# 7 : 11,401
# -0.026%
# --------------------------
# 0 : 94
# 1 : HoloToken
# (HOT)
# 2 : $0.001
#
#
# 0.000001 ETH
# 3 : 0.31%
# 4 : $5,554,784.00
# 5 : $180,637,239.00
# 6 : $180,491,539.78
# 7 : 125,304
# 0.001%
# --------------------------
# 0 : 95
# 1 : yearn.finance
# (YFI)
# 2 : $5,330.82
#
#
# 3.252227 ETH
# 3 : 1.97%
# 4 : $16,627,470.00
# 5 : $176,952,534.00
# 6 : $195,459,846.12
# 7 : 51,974
# 0.015%
# --------------------------
# 0 : 96
# 1 : Livepeer Token
# (LPT)
# 2 : $5.84
#
#
# 0.003563 ETH
# 3 : -2.30%
# 4 : $9,512,317.00
# 5 : $171,385,461.00
# 6 : $145,399,764.80
# 7 : 2,214,783
# -0.001%
# --------------------------
# 0 : 97
# 1 : SwissBorg
# (CHSB)
# 2 : $0.1776
#
#
# 0.000108 ETH
# 3 : 3.16%
# 4 : $779,820.00
# 5 : $169,312,466.00
# 6 : $177,591,000.00
# 7 : 18,478
# 0.000%
# --------------------------
# 0 : 98
# 1 : Blur
# (BLUR)
# 2 : $0.1742
#
#
# 0.000106 ETH
# 3 : 1.20%
# 4 : $22,114,090.00
# 5 : $169,052,418.00
# 6 : $522,690,000.00
# 7 : 41,492
# 0.000%
# --------------------------
# 0 : 99
# 1 : Compound Dai
# (cDAI)
# 2 : $0.0224
#
#
# 0.000014 ETH
# 3 : 0.02%
# 4 : $154.00
# 5 : $166,725,648.00
# 6 : $2,997,776,968.07
# 7 : 17,997
# 0.006%
# --------------------------
# 0 : 100
# 1 : IoTeX Network
# (IOTX)
# 2 : $0.0176
#
#
# 0.000011 ETH
# 3 : 4.51%
# 4 : $9,101,710.00
# 5 : $166,210,929.00
# 6 : $175,998,900.75
# 7 : 21,435
# 0.005%
# --------------------------

# %% [markdown]
# ## Step 4: Create a DataFrame table and write to a CSV file

# %%
import pandas as pd

# %%
# How many rows in the extracted data
len(data)
# Out:
# 100

# %%
data[0]
# Out:
# ['1',
#  'Tether USD\n(USDT)',
#  '$1.00\n\n\n0.000610 ETH',
#  '--',
#  '$16,289,778,116.00',
#  '$83,369,918,594.00',
#  '$39,823,119,845.00',
#  '4,580,187\n-0.094%']

# %%
# Convert the data list to DataFrame object
df = pd.DataFrame(data, columns=col_names)

# %%
df
# Out:
#       #                  Token                        Price Change (%)  \
# 0     1     Tether USD\n(USDT)      $1.00\n\n\n0.000610 ETH         --
# 1     2             BNB\n(BNB)  $212.7004\n\n\n0.129764 ETH      0.05%
# 2     3           USDC\n(USDC)      $1.00\n\n\n0.000610 ETH      0.02%
# 3     4         stETH\n(stETH)  $1,639.23\n\n\n1.000062 ETH     -0.47%
# 4     5            TRON\n(TRX)    $0.0888\n\n\n0.000054 ETH     -0.01%
# ..  ...                    ...                          ...        ...
# 95   96  Livepeer Token\n(LPT)      $5.84\n\n\n0.003563 ETH     -2.30%
# 96   97      SwissBorg\n(CHSB)    $0.1776\n\n\n0.000108 ETH      3.16%
# 97   98           Blur\n(BLUR)    $0.1742\n\n\n0.000106 ETH      1.20%
# 98   99   Compound Dai\n(cDAI)    $0.0224\n\n\n0.000014 ETH      0.02%
# 99  100  IoTeX Network\n(IOTX)    $0.0176\n\n\n0.000011 ETH      4.51%
#
#           Volume (24H) Circulating Market Cap On-Chain Market Cap  \
# 0   $16,289,778,116.00     $83,369,918,594.00  $39,823,119,845.00
# 1      $331,713,816.00     $32,723,133,157.00   $3,526,470,297.89
# 2    $4,270,444,800.00     $25,255,348,953.00  $46,602,430,840.00
# 3        $5,520,449.00     $14,459,518,712.00   $3,038,491,481.07
# 4      $219,852,244.00      $7,904,153,443.00             $230.91
# ..                 ...                    ...                 ...
# 95       $9,512,317.00        $171,385,461.00     $145,399,764.80
# 96         $779,820.00        $169,312,466.00     $177,591,000.00
# 97      $22,114,090.00        $169,052,418.00     $522,690,000.00
# 98             $154.00        $166,725,648.00   $2,997,776,968.07
# 99       $9,101,710.00        $166,210,929.00     $175,998,900.75
#
#                Holders
# 0   4,580,187\n-0.094%
# 1      285,796\n0.009%
# 2   1,790,688\n-0.046%
# 3      270,064\n0.064%
# 4        2,208\n0.317%
# ..                 ...
# 95  2,214,783\n-0.001%
# 96      18,478\n0.000%
# 97      41,492\n0.000%
# 98      17,997\n0.006%
# 99      21,435\n0.005%
#
# [100 rows x 8 columns]

# %% [markdown]
# Split the columns with "\n"

# %%
# Split between token name and token symbol
df[['Token', 'Symbol']] = df['Token'].str.split('\n', expand=True)

# %%
# Split between the USD and ETH prices
df[['Price', 'Price (ETH)']] = df['Price'].str.split('\n\n\n', expand=True)

# %%
# Split the number of holders and percent changes
df[['Holders', 'Holders Change (%)']] = df['Holders'].str.split('\n', expand=True)

# %%
df
# Out:
#       #           Token      Price Change (%)        Volume (24H)  \
# 0     1      Tether USD      $1.00         --  $16,289,778,116.00
# 1     2             BNB  $212.7004      0.05%     $331,713,816.00
# 2     3            USDC      $1.00      0.02%   $4,270,444,800.00
# 3     4           stETH  $1,639.23     -0.47%       $5,520,449.00
# 4     5            TRON    $0.0888     -0.01%     $219,852,244.00
# ..  ...             ...        ...        ...                 ...
# 95   96  Livepeer Token      $5.84     -2.30%       $9,512,317.00
# 96   97       SwissBorg    $0.1776      3.16%         $779,820.00
# 97   98            Blur    $0.1742      1.20%      $22,114,090.00
# 98   99    Compound Dai    $0.0224      0.02%             $154.00
# 99  100   IoTeX Network    $0.0176      4.51%       $9,101,710.00
#
#    Circulating Market Cap On-Chain Market Cap    Holders   Symbol  \
# 0      $83,369,918,594.00  $39,823,119,845.00  4,580,187   (USDT)
# 1      $32,723,133,157.00   $3,526,470,297.89    285,796    (BNB)
# 2      $25,255,348,953.00  $46,602,430,840.00  1,790,688   (USDC)
# 3      $14,459,518,712.00   $3,038,491,481.07    270,064  (stETH)
# 4       $7,904,153,443.00             $230.91      2,208    (TRX)
# ..                    ...                 ...        ...      ...
# 95        $171,385,461.00     $145,399,764.80  2,214,783    (LPT)
# 96        $169,312,466.00     $177,591,000.00     18,478   (CHSB)
# 97        $169,052,418.00     $522,690,000.00     41,492   (BLUR)
# 98        $166,725,648.00   $2,997,776,968.07     17,997   (cDAI)
# 99        $166,210,929.00     $175,998,900.75     21,435   (IOTX)
#
#      Price (ETH) Holders Change (%)
# 0   0.000610 ETH            -0.094%
# 1   0.129764 ETH             0.009%
# 2   0.000610 ETH            -0.046%
# 3   1.000062 ETH             0.064%
# 4   0.000054 ETH             0.317%
# ..           ...                ...
# 95  0.003563 ETH            -0.001%
# 96  0.000108 ETH             0.000%
# 97  0.000106 ETH             0.000%
# 98  0.000014 ETH             0.006%
# 99  0.000011 ETH             0.005%
#
# [100 rows x 11 columns]

# %% [markdown]
# Convert string into numerical columns

# %%
# Regular expression pattern to match numbers
pattern = r'([-+]?\d[\d,]*(?:\.\d+)?)'

# %%
# For each numerical column, convert the string to float numbers
for col_name in df:
    if col_name in ['Token', 'Symbol']:
        continue
    print(col_name)

    # Use df[col_name].str.extract() to extract the numbers and
    # .astype(float) to convert the string to float numbers
    df[col_name] = df[col_name].str.extract(pattern)
    df[col_name] = df[col_name].str.replace(',', '').astype(float)
# Out:
# #
# Price
# Change (%)
# Volume (24H)
# Circulating Market Cap
# On-Chain Market Cap
# Holders
# Price (ETH)
# Holders Change (%)

# %%
df
# Out:
#         #           Token      Price  Change (%)  Volume (24H)  \
# 0     1.0      Tether USD     1.0000         NaN  1.628978e+10
# 1     2.0             BNB   212.7004        0.05  3.317138e+08
# 2     3.0            USDC     1.0000        0.02  4.270445e+09
# 3     4.0           stETH  1639.2300       -0.47  5.520449e+06
# 4     5.0            TRON     0.0888       -0.01  2.198522e+08
# ..    ...             ...        ...         ...           ...
# 95   96.0  Livepeer Token     5.8400       -2.30  9.512317e+06
# 96   97.0       SwissBorg     0.1776        3.16  7.798200e+05
# 97   98.0            Blur     0.1742        1.20  2.211409e+07
# 98   99.0    Compound Dai     0.0224        0.02  1.540000e+02
# 99  100.0   IoTeX Network     0.0176        4.51  9.101710e+06
#
#     Circulating Market Cap  On-Chain Market Cap    Holders   Symbol  \
# 0             8.336992e+10         3.982312e+10  4580187.0   (USDT)
# 1             3.272313e+10         3.526470e+09   285796.0    (BNB)
# 2             2.525535e+10         4.660243e+10  1790688.0   (USDC)
# 3             1.445952e+10         3.038491e+09   270064.0  (stETH)
# 4             7.904153e+09         2.309100e+02     2208.0    (TRX)
# ..                     ...                  ...        ...      ...
# 95            1.713855e+08         1.453998e+08  2214783.0    (LPT)
# 96            1.693125e+08         1.775910e+08    18478.0   (CHSB)
# 97            1.690524e+08         5.226900e+08    41492.0   (BLUR)
# 98            1.667256e+08         2.997777e+09    17997.0   (cDAI)
# 99            1.662109e+08         1.759989e+08    21435.0   (IOTX)
#
#     Price (ETH)  Holders Change (%)
# 0      0.000610              -0.094
# 1      0.129764               0.009
# 2      0.000610              -0.046
# 3      1.000062               0.064
# 4      0.000054               0.317
# ..          ...                 ...
# 95     0.003563              -0.001
# 96     0.000108               0.000
# 97     0.000106               0.000
# 98     0.000014               0.006
# 99     0.000011               0.005
#
# [100 rows x 11 columns]

# %% [markdown]
# Last but not least, remove the bracket in token symbol column

# %%
df['Symbol'] = df['Symbol'].str.extract('\((.*?)\)')

# %%
df
# Out:
#         #           Token      Price  Change (%)  Volume (24H)  \
# 0     1.0      Tether USD     1.0000         NaN  1.628978e+10
# 1     2.0             BNB   212.7004        0.05  3.317138e+08
# 2     3.0            USDC     1.0000        0.02  4.270445e+09
# 3     4.0           stETH  1639.2300       -0.47  5.520449e+06
# 4     5.0            TRON     0.0888       -0.01  2.198522e+08
# ..    ...             ...        ...         ...           ...
# 95   96.0  Livepeer Token     5.8400       -2.30  9.512317e+06
# 96   97.0       SwissBorg     0.1776        3.16  7.798200e+05
# 97   98.0            Blur     0.1742        1.20  2.211409e+07
# 98   99.0    Compound Dai     0.0224        0.02  1.540000e+02
# 99  100.0   IoTeX Network     0.0176        4.51  9.101710e+06
#
#     Circulating Market Cap  On-Chain Market Cap    Holders Symbol  \
# 0             8.336992e+10         3.982312e+10  4580187.0   USDT
# 1             3.272313e+10         3.526470e+09   285796.0    BNB
# 2             2.525535e+10         4.660243e+10  1790688.0   USDC
# 3             1.445952e+10         3.038491e+09   270064.0  stETH
# 4             7.904153e+09         2.309100e+02     2208.0    TRX
# ..                     ...                  ...        ...    ...
# 95            1.713855e+08         1.453998e+08  2214783.0    LPT
# 96            1.693125e+08         1.775910e+08    18478.0   CHSB
# 97            1.690524e+08         5.226900e+08    41492.0   BLUR
# 98            1.667256e+08         2.997777e+09    17997.0   cDAI
# 99            1.662109e+08         1.759989e+08    21435.0   IOTX
#
#     Price (ETH)  Holders Change (%)
# 0      0.000610              -0.094
# 1      0.129764               0.009
# 2      0.000610              -0.046
# 3      1.000062               0.064
# 4      0.000054               0.317
# ..          ...                 ...
# 95     0.003563              -0.001
# 96     0.000108               0.000
# 97     0.000106               0.000
# 98     0.000014               0.006
# 99     0.000011               0.005
#
# [100 rows x 11 columns]

# %% [markdown]
# Write the DataFrame table to CSV

# %%
df.to_csv('token_prices.csv', index=False)
